# %%
import pandas as pd
import glob

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-137e9070-48e8-4af9-97b9-e25971cd357a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-137e9070-48e8-4af9-97b9-e25971cd357a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sub_1.csv to sub_1 (1).csv
# Saving sub_1_dws1.csv to sub_1_dws1 (1).csv
# Saving sub_1_dws2.csv to sub_1_dws2 (1).csv
# Saving sub_1_dws11.csv to sub_1_dws11 (1).csv
# Saving sub_1_jog9.csv to sub_1_jog9 (1).csv
# Saving sub_1_jog16.csv to sub_1_jog16 (1).csv
# Saving sub_1_sit5.csv to sub_1_sit5 (1).csv
# Saving sub_1_sit13.csv to sub_1_sit13 (1).csv
# Saving sub_1_std6.csv to sub_1_std6 (1).csv
# Saving sub_1_std14.csv to sub_1_std14 (1).csv
# Saving sub_1_ups3.csv to sub_1_ups3 (1).csv
# Saving sub_1_ups4.csv to sub_1_ups4 (1).csv
# ...

# %%
# merging all HeightGroup1 csv files from wlk_7
wlk7_HeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_3.csv', 'sub_5.csv', 'sub_7.csv', 'sub_8.csv', 'sub_10.csv', 'sub_12.csv', 'sub_18.csv', 'sub_19.csv', 'sub_21.csv', 'sub_23.csv', 'sub_24.csv']), ignore_index=True)
print(wlk7_HeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.959818       -1.462167      1.432332   0.100293
# 1               1       2.011369       -1.456576      1.482870   0.103072
# 2               2       2.075497       -1.449990      1.540119   0.105472
# 3               3       2.126304       -1.446606      1.582288   0.105232
# 4               4       2.208217       -1.441369      1.657403   0.103709
# ...           ...            ...             ...           ...        ...
# 71236        5016       1.456354        0.025356      2.896466   0.993139
# 71237        5017       1.435872       -0.007495      2.934749   0.990884
# 71238        5018       1.438846       -0.054606      2.985588   0.989830
# 71239        5019       1.454454       -0.112258      3.026277   0.986988
# 71240        5020       1.437505       -0.167232      3.047170   0.977303
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
wlk7_HeightGroup1_df = wlk7_HeightGroup1_df.iloc[: , 1:]
wlk7_HeightGroup1_df.shape
# Out:
# (71241, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk7_HeightGroup1_df["Activity"] = 'Walking' 
wlk7_HeightGroup1_df.shape
# Out:
# (71241, 13)

# %%
# merging all HeightGroup2 csv files from wlk_7
wlk7_HeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1.csv', 'sub_2.csv', 'sub_4.csv', 'sub_6.csv', 'sub_9.csv', 'sub_11.csv', 'sub_13.csv', 'sub_14.csv', 'sub_15.csv', 'sub_16.csv', 'sub_17.csv', 'sub_20.csv', 'sub_22.csv']), ignore_index=True)
print(wlk7_HeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -1.711140       -1.429168     -2.591433  -0.139767
# 1               1      -1.787917       -1.414171     -2.630956  -0.152324
# 2               2      -1.897323       -1.399331     -2.706668  -0.161610
# 3               3      -2.018375       -1.383279     -2.813421  -0.168058
# 4               4      -2.124395       -1.364054     -2.913092  -0.174613
# ...           ...            ...             ...           ...        ...
# 87399        6437       0.820939       -1.010720     -0.679626   0.388757
# 87400        6438       0.812806       -0.966541     -0.656513   0.412596
# 87401        6439       0.803715       -0.939513     -0.626011   0.424890
# 87402        6440       0.783811       -0.914628     -0.599212   0.430707
# 87403        6441       0.758766       -0.895560     -0.577389   0.430069
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
wlk7_HeightGroup2_df = wlk7_HeightGroup2_df.iloc[: , 1:]
wlk7_HeightGroup2_df.shape
# Out:
# (87404, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk7_HeightGroup2_df["Activity"] = 'Walking' 
wlk7_HeightGroup2_df.shape
# Out:
# (87404, 13)

# %%
# merging all HeightGroup1 csv files from wlk_8
wlk8_HeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_3_w8.csv', 'sub_5_w8.csv', 'sub_7_w8.csv', 'sub_8_w8.csv', 'sub_10_w8.csv', 'sub_12_w8.csv', 'sub_18_w8.csv', 'sub_19_w8.csv', 'sub_21_w8.csv', 'sub_23_w8.csv', 'sub_24_w8.csv']), ignore_index=True)
print(wlk8_HeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.342161       -1.228059      2.729128   0.327319
# 1               1       1.301643       -1.223361      2.711964   0.328227
# 2               2       1.283964       -1.216824      2.704733   0.332463
# 3               3       1.286451       -1.203136      2.717144   0.344998
# 4               4       1.233368       -1.187758      2.682898   0.352664
# ...           ...            ...             ...           ...        ...
# 56801        4071       0.732151       -1.023012     -2.798738   0.348138
# 56802        4072       0.719940       -0.958009     -2.811475   0.379219
# 56803        4073       0.738723       -0.946121     -2.745565   0.393794
# 56804        4074       0.722347       -0.976487     -2.779944   0.370201
# 56805        4075       0.700401       -0.988938     -2.833834   0.354216
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
wlk8_HeightGroup1_df = wlk8_HeightGroup1_df.iloc[: , 1:]
wlk8_HeightGroup1_df.shape
# Out:
# (56806, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk8_HeightGroup1_df["Activity"] = 'Walking' 
wlk8_HeightGroup1_df.shape
# Out:
# (56806, 13)

# %%
# merging all HeightGroup2 csv files from wlk_8
wlk8_HeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_w8.csv', 'sub_2_w8.csv', 'sub_4_w8.csv', 'sub_6_w8.csv', 'sub_9_w8.csv', 'sub_11_w8.csv', 'sub_13_w8.csv', 'sub_14_w8.csv', 'sub_15_w8.csv', 'sub_16_w8.csv', 'sub_17_w8.csv', 'sub_20_w8.csv', 'sub_22_w8.csv']), ignore_index=True)
print(wlk8_HeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       2.255404       -1.421448      1.482931   0.115265
# 1               1       1.960381       -1.423633      1.195886   0.135644
# 2               2       1.648809       -1.412348      0.888191   0.157306
# 3               3       1.342174       -1.388827      0.616273   0.176258
# 4               4       1.121672       -1.355100      0.449400   0.192801
# ...           ...            ...             ...           ...        ...
# 63560        4943       0.941090       -1.092168      0.900210   0.372226
# 63561        4944       0.929729       -1.126047      0.878770   0.344811
# 63562        4945       0.927453       -1.159592      0.877930   0.319807
# 63563        4946       0.961754       -1.195810      0.910480   0.300404
# 63564        4947       1.041013       -1.233225      0.977956   0.285793
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
wlk8_HeightGroup2_df = wlk8_HeightGroup2_df.iloc[: , 1:]
wlk8_HeightGroup2_df.shape
# Out:
# (63565, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk8_HeightGroup2_df["Activity"] = 'Walking' 
wlk8_HeightGroup2_df.shape
# Out:
# (63565, 13)

# %%
# merging all HeightGroup1 csv files from wlk_15
wlk15_HeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_3_wlk15.csv', 'sub_5_wlk15.csv', 'sub_7_wlk15.csv', 'sub_8_wlk15.csv', 'sub_10_wlk15.csv', 'sub_18_wlk15.csv', 'sub_19_wlk15.csv', 'sub_21_wlk15.csv', 'sub_23_wlk15.csv', 'sub_24_wlk15.csv']), ignore_index=True)
print(wlk15_HeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.320966       -1.185376     -0.185139   0.118605
# 1               1       0.309780       -1.194660     -0.206318   0.111979
# 2               2       0.292629       -1.209627     -0.235917   0.101935
# 3               3       0.281451       -1.235911     -0.263848   0.091284
# 4               4       0.291753       -1.269970     -0.269821   0.085226
# ...           ...            ...             ...           ...        ...
# 28032        2055      -1.287175       -1.180782      1.184133  -0.365012
# 28033        2056      -1.217304       -1.160821      1.208497  -0.373942
# 28034        2057      -1.083201       -1.167077      1.269294  -0.347061
# 28035        2058      -0.966096       -1.193223      1.348783  -0.303291
# 28036        2059      -0.989568       -1.205294      1.358403  -0.298726
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
wlk15_HeightGroup1_df = wlk15_HeightGroup1_df.iloc[: , 1:]
wlk15_HeightGroup1_df.shape
# Out:
# (28037, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk15_HeightGroup1_df["Activity"] = 'Walking' 
wlk15_HeightGroup1_df.shape
# Out:
# (28037, 13)

# %%
# merging all HeightGroup2 csv files from wlk_15
wlk15_HeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_wlk15.csv', 'sub_2_wlk15.csv', 'sub_4_wlk15.csv', 'sub_6_wlk15.csv', 'sub_9_wlk15.csv', 'sub_11_wlk15.csv', 'sub_13_wlk15.csv', 'sub_14_wlk15.csv', 'sub_16_wlk15.csv', 'sub_17_wlk15.csv', 'sub_20_wlk15.csv', 'sub_22_wlk15.csv']), ignore_index=True)
print(wlk15_HeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -0.642341       -1.408409     -1.725791  -0.096855
# 1               1      -1.063803       -1.440007     -2.200242  -0.114011
# 2               2      -1.258381       -1.432875     -2.424099  -0.130829
# 3               3      -1.391648       -1.420133     -2.584396  -0.147692
# 4               4      -1.602210       -1.412241     -2.812153  -0.157814
# ...           ...            ...             ...           ...        ...
# 32034        2368       0.652484       -0.807196      0.146552   0.419865
# 32035        2369       0.622831       -0.843409      0.138808   0.387870
# 32036        2370       0.617302       -0.846571      0.128739   0.383509
# 32037        2371       0.645521       -0.830476      0.144746   0.405800
# 32038        2372       0.660655       -0.824494      0.171551   0.416610
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
wlk15_HeightGroup2_df = wlk15_HeightGroup2_df.iloc[: , 1:]
wlk15_HeightGroup2_df.shape
# Out:
# (32039, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk15_HeightGroup2_df["Activity"] = 'Walking' 
wlk15_HeightGroup2_df.shape
# Out:
# (32039, 13)

# %%
# merging all HeightGroup1 csv files from std_6
std6_HeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_3_std6.csv', 'sub_5_std6.csv', 'sub_7_std6.csv', 'sub_8_std6.csv', 'sub_10_std6.csv', 'sub_12_std6.csv', 'sub_18_std6.csv', 'sub_19_std6.csv', 'sub_21_std6.csv', 'sub_23_std6.csv', 'sub_24_std6.csv']), ignore_index=True)
print(std6_HeightGroup1_df)
# Out:
#         Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0                0       1.059946       -1.331125      0.093850   0.207040
# 1                1       1.041740       -1.324215      0.074434   0.210685
# 2                2       1.026708       -1.318294      0.058913   0.213720
# 3                3       1.015559       -1.313506      0.048103   0.216203
# 4                4       1.007940       -1.310110      0.041727   0.217952
# ...            ...            ...             ...           ...        ...
# 108077       10968       0.024580       -1.445235     -1.865114   0.003078
# 108078       10969       0.035625       -1.444928     -1.845826   0.004471
# 108079       10970       0.047078       -1.444934     -1.826624   0.005908
# 108080       10971       0.058243       -1.445177     -1.808854   0.007293
# 108081       10972       0.068046       -1.445550     -1.793355   0.008494
#
# ...

# %%
# Drop first column of dataframe
std6_HeightGroup1_df = std6_HeightGroup1_df.iloc[: , 1:]
std6_HeightGroup1_df.shape
# Out:
# (108082, 12)

# %%
# Add Class Variable "Activity" in dataframe
std6_HeightGroup1_df["Activity"] = 'Standing' 
std6_HeightGroup1_df.shape
# Out:
# (108082, 13)

# %%
# merging all HeightGroup2 csv files from std_6
std6_HeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_std6.csv', 'sub_2_std6.csv', 'sub_4_std6.csv', 'sub_6_std6.csv', 'sub_9_std6.csv', 'sub_11_std6.csv', 'sub_13_std6.csv', 'sub_14_std6.csv', 'sub_15_std6.csv', 'sub_16_std6.csv', 'sub_17_std6.csv', 'sub_20_std6.csv', 'sub_22_std6.csv']), ignore_index=True)
print(std6_HeightGroup2_df)
# Out:
#         Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0                0       2.489271       -1.397067      1.899690   0.104929
# 1                1       2.488154       -1.396068      1.905025   0.105682
# 2                2       2.489687       -1.394939      1.912298   0.106144
# 3                3       2.494505       -1.393874      1.922063   0.106105
# 4                4       2.500577       -1.393094      1.931172   0.105709
# ...            ...            ...             ...           ...        ...
# 116729        7622      -1.197682       -1.477199     -1.878977  -0.086168
# 116730        7623      -1.272631       -1.480059     -1.949962  -0.085695
# 116731        7624      -1.347158       -1.483424     -2.019999  -0.084103
# 116732        7625      -1.416108       -1.486702     -2.084729  -0.081949
# 116733        7626      -1.480307       -1.489345     -2.145587  -0.079933
#
# ...

# %%
# Drop first column of dataframe 
std6_HeightGroup2_df = std6_HeightGroup2_df.iloc[: , 1:]
std6_HeightGroup2_df.shape
# Out:
# (116734, 12)

# %%
# Add Class Variable "Activity" in dataframe
std6_HeightGroup2_df["Activity"] = 'Standing' 
std6_HeightGroup2_df.shape
# Out:
# (116734, 13)

# %%
# merging all HeightGroup1 csv files from std_14
std14_HeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_3_std14.csv', 'sub_5_std14.csv', 'sub_7_std14.csv', 'sub_8_std14.csv', 'sub_10_std14.csv', 'sub_12_std14.csv', 'sub_18_std14.csv', 'sub_19_std14.csv', 'sub_21_std14.csv', 'sub_23_std14.csv', 'sub_24_std14.csv']), ignore_index=True)
print(std14_HeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.523998       -1.187632      1.451139   0.373440
# 1               1       1.524484       -1.188099      1.450162   0.373016
# 2               2       1.524169       -1.188614      1.448443   0.372534
# 3               3       1.522555       -1.189332      1.444639   0.371839
# 4               4       1.519942       -1.190178      1.439114   0.371006
# ...           ...            ...             ...           ...        ...
# 36301        3964      -2.512274       -1.475547      0.560892  -0.055978
# 36302        3965      -2.514569       -1.474699      0.558068  -0.056297
# 36303        3966      -2.517105       -1.473640      0.555248  -0.056716
# 36304        3967      -2.515195       -1.472593      0.557282  -0.057477
# 36305        3968      -2.512655       -1.471566      0.560290  -0.058280
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
std14_HeightGroup1_df = std14_HeightGroup1_df.iloc[: , 1:]
std14_HeightGroup1_df.shape
# Out:
# (36306, 12)

# %%
# Add Class Variable "Activity" in dataframe
std14_HeightGroup1_df["Activity"] = 'Standing' 
std14_HeightGroup1_df.shape
# Out:
# (36306, 13)

# %%
# merging all HeightGroup2 csv files from std_14
std14_HeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_std14.csv', 'sub_2_std14.csv', 'sub_4_std14.csv', 'sub_6_std14.csv', 'sub_9_std14.csv', 'sub_11_std14.csv', 'sub_13_std14.csv', 'sub_14_std14.csv', 'sub_15_std14.csv', 'sub_16_std14.csv', 'sub_17_std14.csv', 'sub_20_std14.csv', 'sub_22_std14.csv']), ignore_index=True)
print(std14_HeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.573929       -1.051363      1.611548   0.496386
# 1               1       1.573086       -1.051097      1.611145   0.496618
# 2               2       1.574466       -1.050255      1.612825   0.497346
# 3               3       1.574735       -1.053220      1.614236   0.494771
# 4               4       1.577461       -1.054274      1.618206   0.493848
# ...           ...            ...             ...           ...        ...
# 45300        5774      -0.619835       -1.350551      2.879654  -0.126790
# 45301        5775      -0.619461       -1.350649      2.877945  -0.126668
# 45302        5776      -0.619264       -1.350392      2.876637  -0.126779
# 45303        5777      -0.619338       -1.349851      2.875683  -0.127099
# 45304        5778      -0.619668       -1.349268      2.874892  -0.127489
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe 
std14_HeightGroup2_df = std14_HeightGroup2_df.iloc[: , 1:]
std14_HeightGroup2_df.shape
# Out:
# (45305, 12)

# %%
# Add Class Variable "Activity" in dataframe
std14_HeightGroup2_df["Activity"] = 'Standing' 
std14_HeightGroup2_df.shape
# Out:
# (45305, 13)

# %%
# merging all HeightGroup1 csv files from sit_5
sit5_HeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_3_sit5.csv', 'sub_5_sit5.csv', 'sub_7_sit5.csv', 'sub_8_sit5.csv', 'sub_10_sit5.csv', 'sub_12_sit5.csv', 'sub_18_sit5.csv', 'sub_19_sit5.csv', 'sub_21_sit5.csv', 'sub_23_sit5.csv', 'sub_24_sit5.csv']), ignore_index=True)
print(sit5_HeightGroup1_df)
# Out:
#         Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0                0       0.647226       -0.338232      0.593338   0.568812
# 1                1       0.645525       -0.336553      0.590098   0.567865
# 2                2       0.642707       -0.335555      0.585106   0.565936
# 3                3       0.640522       -0.334522      0.578715   0.564486
# 4                4       0.639977       -0.333256      0.571930   0.564321
# ...            ...            ...             ...           ...        ...
# 108127       10683      -2.563484       -0.149645     -0.322130  -0.540334
# 108128       10684      -2.559251       -0.157457     -0.316592  -0.543177
# 108129       10685      -2.554478       -0.161579     -0.309695  -0.546746
# 108130       10686      -2.549122       -0.163005     -0.302709  -0.551010
# 108131       10687      -2.542947       -0.165970     -0.295609  -0.555781
#
# ...

# %%
# Drop first column of dataframe
sit5_HeightGroup1_df = sit5_HeightGroup1_df.iloc[: , 1:]
sit5_HeightGroup1_df.shape
# Out:
# (108132, 12)

# %%
# Add Class Variable "Activity" in dataframe
sit5_HeightGroup1_df["Activity"] = 'Sitting' 
sit5_HeightGroup1_df.shape
# Out:
# (108132, 13)

# %%
# merging all HeightGroup2 csv files from sit_5
sit5_HeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_sit5.csv', 'sub_2_sit5.csv', 'sub_4_sit5.csv', 'sub_6_sit5.csv', 'sub_9_sit5.csv', 'sub_11_sit5.csv', 'sub_13_sit5.csv', 'sub_14_sit5.csv', 'sub_15_sit5.csv', 'sub_16_sit5.csv', 'sub_17_sit5.csv', 'sub_20_sit5.csv', 'sub_22_sit5.csv']), ignore_index=True)
print(sit5_HeightGroup2_df)
# Out:
#         Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0                0       0.351138       -0.416302     -0.098023   0.314588
# 1                1       0.351219       -0.416372     -0.098025   0.314649
# 2                2       0.351145       -0.416497     -0.098045   0.314567
# 3                3       0.350849       -0.416695     -0.098148   0.314286
# 4                4       0.350859       -0.416863     -0.098022   0.314271
# ...            ...            ...             ...           ...        ...
# 126520        8461       0.414219       -0.237713      1.090686   0.391157
# 126521        8462       0.414810       -0.237391      1.089693   0.391714
# 126522        8463       0.415104       -0.237104      1.088961   0.392002
# 126523        8464       0.415130       -0.236966      1.088600   0.392038
# 126524        8465       0.414942       -0.236914      1.088706   0.391876
#
# ...

# %%
# Drop first column of dataframe
sit5_HeightGroup2_df = sit5_HeightGroup2_df.iloc[: , 1:]
sit5_HeightGroup2_df.shape
# Out:
# (126525, 12)

# %%
# Add Class Variable "Activity" in dataframe
sit5_HeightGroup2_df["Activity"] = 'Sitting' 
sit5_HeightGroup2_df.shape
# Out:
# (126525, 13)

# %%
# merging all HeightGroup1 csv files from sit_13
sit13_HeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_3_sit13.csv', 'sub_5_sit13.csv', 'sub_7_sit13.csv', 'sub_8_sit13.csv', 'sub_10_sit13.csv', 'sub_12_sit13.csv', 'sub_18_sit13.csv', 'sub_19_sit13.csv', 'sub_21_sit13.csv', 'sub_23_sit13.csv', 'sub_24_sit13.csv']), ignore_index=True)
print(sit13_HeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.614776       -0.471108      0.370743   0.513944
# 1               1       0.612136       -0.475710      0.370974   0.510815
# 2               2       0.613886       -0.475699      0.369143   0.512090
# 3               3       0.614193       -0.473767      0.368799   0.512822
# 4               4       0.615503       -0.472237      0.371684   0.514176
# ...           ...            ...             ...           ...        ...
# 44631        3381      -2.368280       -0.381075     -0.089417  -0.648402
# 44632        3382      -2.368752       -0.381071     -0.089478  -0.648090
# 44633        3383      -2.369130       -0.381163     -0.089465  -0.647814
# 44634        3384      -2.369372       -0.381295     -0.089468  -0.647619
# 44635        3385      -2.369404       -0.381297     -0.089545  -0.647598
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
sit13_HeightGroup1_df = sit13_HeightGroup1_df.iloc[: , 1:]
sit13_HeightGroup1_df.shape
# Out:
# (44636, 12)

# %%
# Add Class Variable "Activity" in dataframe
sit13_HeightGroup1_df["Activity"] = 'Sitting' 
sit13_HeightGroup1_df.shape
# Out:
# (44636, 13)

# %%
# merging all HeightGroup2 csv files from sit_13
sit13_HeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_sit13.csv', 'sub_2_sit13.csv', 'sub_4_sit13.csv', 'sub_6_sit13.csv', 'sub_9_sit13.csv', 'sub_11_sit13.csv', 'sub_13_sit13.csv', 'sub_14_sit13.csv', 'sub_15_sit13.csv', 'sub_16_sit13.csv', 'sub_17_sit13.csv', 'sub_20_sit13.csv', 'sub_22_sit13.csv']), ignore_index=True)
print(sit13_HeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.351138       -0.416302     -0.098023   0.314588
# 1               1       0.351219       -0.416372     -0.098025   0.314649
# 2               2       0.351145       -0.416497     -0.098045   0.314567
# 3               3       0.350849       -0.416695     -0.098148   0.314286
# 4               4       0.350859       -0.416863     -0.098022   0.314271
# ...           ...            ...             ...           ...        ...
# 59480        3552       0.449772        0.012088      0.112036   0.434728
# 59481        3553       0.449075        0.013243      0.111479   0.434094
# 59482        3554       0.448561        0.014333      0.110953   0.433625
# 59483        3555       0.447085        0.015270      0.110621   0.432288
# 59484        3556       0.445072        0.015881      0.110639   0.430468
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
sit13_HeightGroup2_df = sit13_HeightGroup2_df.iloc[: , 1:]
sit13_HeightGroup2_df.shape
# Out:
# (59485, 12)

# %%
# Add Class Variable "Activity" in dataframe
sit13_HeightGroup2_df["Activity"] = 'Sitting' 
sit13_HeightGroup2_df.shape
# Out:
# (59485, 13)

# %%
# merging all HeightGroup1 csv files from jog_9
jog9_HeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_3_jog9.csv', 'sub_5_jog9.csv', 'sub_7_jog9.csv', 'sub_8_jog9.csv', 'sub_10_jog9.csv', 'sub_12_jog9.csv', 'sub_18_jog9.csv', 'sub_19_jog9.csv', 'sub_21_jog9.csv', 'sub_23_jog9.csv', 'sub_24_jog9.csv']), ignore_index=True)
print(jog9_HeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.427641       -1.256756     -0.204623   0.128103
# 1               1       0.365072       -1.268669     -0.243717   0.106225
# 2               2       0.291153       -1.281348     -0.284730   0.081928
# 3               3       0.259027       -1.296166     -0.289536   0.069458
# 4               4       0.292313       -1.309405     -0.247238   0.074464
# ...           ...            ...             ...           ...        ...
# 49296        2838      -1.017175       -1.162354     -1.310722  -0.337852
# 49297        2839      -1.292318       -1.078857     -1.562349  -0.454140
# 49298        2840      -1.403760       -0.951444     -1.709745  -0.572428
# 49299        2841      -1.504000       -0.843886     -1.828078  -0.663082
# 49300        2842      -1.550190       -0.746814     -1.889135  -0.733701
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
jog9_HeightGroup1_df = jog9_HeightGroup1_df.iloc[: , 1:]
jog9_HeightGroup1_df.shape
# Out:
# (49301, 12)

# %%
# Add Class Variable "Activity" in dataframe
jog9_HeightGroup1_df["Activity"] = 'Jogging' 
jog9_HeightGroup1_df.shape
# Out:
# (49301, 13)

# %%
# merging all HeightGroup2 csv files from jog_9
jog9_HeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_jog9.csv', 'sub_2_jog9.csv', 'sub_4_jog9.csv', 'sub_6_jog9.csv', 'sub_9_jog9.csv', 'sub_11_jog9.csv', 'sub_13_jog9.csv', 'sub_14_jog9.csv', 'sub_15_jog9.csv', 'sub_16_jog9.csv', 'sub_17_jog9.csv', 'sub_20_jog9.csv', 'sub_22_jog9.csv']), ignore_index=True)
print(jog9_HeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       3.058304       -1.227988      2.570999   0.027964
# 1               1       3.075964       -1.225818      2.615277   0.022178
# 2               2       3.103364       -1.235013      2.651791   0.012594
# 3               3       3.109208       -1.244901      2.678484   0.010366
# 4               4       3.074214       -1.263514      2.661371   0.020364
# ...           ...            ...             ...           ...        ...
# 55021        4808       1.009935       -1.168745     -2.709150   0.331332
# 55022        4809       1.029138       -1.194641     -2.717922   0.314736
# 55023        4810       1.011173       -1.238663     -2.711134   0.276290
# 55024        4811       1.046748       -1.275486     -2.665642   0.251943
# 55025        4812       1.111508       -1.308082     -2.611691   0.232745
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
jog9_HeightGroup2_df = jog9_HeightGroup2_df.iloc[: , 1:]
jog9_HeightGroup2_df.shape
# Out:
# (55026, 12)

# %%
# Add Class Variable "Activity" in dataframe
jog9_HeightGroup2_df["Activity"] = 'Jogging' 
jog9_HeightGroup2_df.shape
# Out:
# (55026, 13)

# %%
# merging all HeightGroup1 csv files from jog_16
jog16_HeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_3_jog16.csv', 'sub_5_jog16.csv', 'sub_7_jog16.csv', 'sub_8_jog16.csv', 'sub_10_jog16.csv', 'sub_12_jog16.csv', 'sub_18_jog16.csv', 'sub_19_jog16.csv', 'sub_21_jog16.csv', 'sub_23_jog16.csv', 'sub_24_jog16.csv']), ignore_index=True)
print(jog16_HeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.241369       -1.345856      0.403204   0.211029
# 1               1       0.968561       -1.304025      0.134961   0.217223
# 2               2       0.875571       -1.224026     -0.015112   0.260973
# 3               3       0.869086       -1.195502     -0.100072   0.279936
# 4               4       0.868492       -1.221096     -0.102839   0.261527
# ...           ...            ...             ...           ...        ...
# 14017         785      -1.553643       -1.207026     -2.015848  -0.355748
# 14018         786      -1.533934       -1.243476     -2.010537  -0.321289
# 14019         787      -1.301587       -1.362634     -1.783378  -0.199218
# 14020         788      -0.524913       -1.486641     -0.952944  -0.042124
# 14021         789       0.683482       -1.435057      0.377682   0.085456
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
jog16_HeightGroup1_df = jog16_HeightGroup1_df.iloc[: , 1:]
jog16_HeightGroup1_df.shape
# Out:
# (14022, 12)

# %%
# Add Class Variable "Activity" in dataframe
jog16_HeightGroup1_df["Activity"] = 'Jogging' 
jog16_HeightGroup1_df.shape
# Out:
# (14022, 13)

# %%
# merging all HeightGroup2 csv files from jog_16
jog16_HeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_jog16.csv', 'sub_2_jog16.csv', 'sub_4_jog16.csv', 'sub_6_jog16.csv', 'sub_9_jog16.csv', 'sub_11_jog16.csv', 'sub_13_jog16.csv', 'sub_14_jog16.csv', 'sub_15_jog16.csv', 'sub_16_jog16.csv', 'sub_17_jog16.csv', 'sub_20_jog16.csv', 'sub_22_jog16.csv']), ignore_index=True)
print(jog16_HeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       2.135357       -1.138555      1.678900   0.353903
# 1               1       2.162745       -1.152928      1.739330   0.336766
# 2               2       2.175561       -1.166584      1.770651   0.323538
# 3               3       2.105621       -1.194708      1.696332   0.315997
# 4               4       2.021151       -1.202365      1.626949   0.324243
# ...           ...            ...             ...           ...        ...
# 15877        1463       2.625511       -1.444273      0.859824   0.062197
# 15878        1464       2.983922       -1.442248      1.179851   0.020106
# 15879        1465      -3.019766       -1.433483      1.426805  -0.016618
# 15880        1466      -2.837716       -1.423747      1.585341  -0.043803
# 15881        1467      -2.751986       -1.425407      1.669631  -0.054978
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
jog16_HeightGroup2_df = jog16_HeightGroup2_df.iloc[: , 1:]
jog16_HeightGroup2_df.shape
# Out:
# (15882, 12)

# %%
# Add Class Variable "Activity" in dataframe
jog16_HeightGroup2_df["Activity"] = 'Jogging' 
jog16_HeightGroup2_df.shape
# Out:
# (15882, 13)

# %%
# merging all HeightGroup1 csv files from dws_1
dws1_HeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_3_dws1.csv', 'sub_5_dws1.csv', 'sub_7_dws1.csv', 'sub_8_dws1.csv', 'sub_10_dws1.csv', 'sub_12_dws1.csv', 'sub_18_dws1.csv', 'sub_19_dws1.csv', 'sub_21_dws1.csv', 'sub_23_dws1.csv', 'sub_24_dws1.csv']), ignore_index=True)
print(dws1_HeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.627059       -1.058523      0.278144   0.287608
# 1               1       0.628015       -1.043158      0.275923   0.295822
# 2               2       0.634446       -1.041952      0.289878   0.299053
# 3               3       0.638048       -1.052550      0.309340   0.295048
# 4               4       0.645913       -1.068337      0.329102   0.289876
# ...           ...            ...             ...           ...        ...
# 24594        1642       1.900272       -1.384036      1.070332   0.175689
# 24595        1643       1.996873       -1.369482      1.160633   0.182080
# 24596        1644       2.074751       -1.350028      1.228313   0.191755
# 24597        1645       2.139869       -1.337114      1.289072   0.195067
# 24598        1646       2.272042       -1.327628      1.417406   0.183965
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws1_HeightGroup1_df = dws1_HeightGroup1_df.iloc[: , 1:]
dws1_HeightGroup1_df.shape
# Out:
# (24599, 12)

# %%
# Add Class Variable "Activity" in dataframe
dws1_HeightGroup1_df["Activity"] = 'Walking_DownStairs' 
dws1_HeightGroup1_df.shape
# Out:
# (24599, 13)

# %%
# merging all HeightGroup2 csv files from dws_1
dws1_HeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_dws1.csv', 'sub_2_dws1.csv', 'sub_4_dws1.csv', 'sub_6_dws1.csv', 'sub_9_dws1.csv', 'sub_11_dws1.csv', 'sub_13_dws1.csv', 'sub_14_dws1.csv', 'sub_15_dws1.csv', 'sub_16_dws1.csv', 'sub_17_dws1.csv', 'sub_20_dws1.csv', 'sub_22_dws1.csv']), ignore_index=True)
print(dws1_HeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.528132       -0.733896      0.696372   0.741895
# 1               1       1.527992       -0.716987      0.677762   0.753099
# 2               2       1.527765       -0.706999      0.670951   0.759611
# 3               3       1.516768       -0.704678      0.675735   0.760709
# 4               4       1.493941       -0.703918      0.672994   0.760062
# ...           ...            ...             ...           ...        ...
# 25642        1819       0.654484       -1.046152     -2.750981   0.304922
# 25643        1820       0.665439       -0.992830     -2.730912   0.337297
# 25644        1821       0.680146       -0.961199     -2.717366   0.360069
# 25645        1822       0.709875       -0.950585     -2.699831   0.378791
# 25646        1823       0.744389       -0.954610     -2.671356   0.391555
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws1_HeightGroup2_df = dws1_HeightGroup2_df.iloc[: , 1:]
dws1_HeightGroup2_df.shape
# Out:
# (25647, 12)

# %%
# Add Class Variable "Activity" in dataframe
dws1_HeightGroup2_df["Activity"] = 'Walking_DownStairs' 
dws1_HeightGroup2_df.shape
# Out:
# (25647, 13)

# %%
# merging all HeightGroup1 csv files from dws_2
dws2_HeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_3_dws2.csv', 'sub_5_dws2.csv', 'sub_7_dws2.csv', 'sub_8_dws2.csv', 'sub_10_dws2.csv', 'sub_12_dws2.csv', 'sub_18_dws2.csv', 'sub_19_dws2.csv', 'sub_21_dws2.csv', 'sub_23_dws2.csv', 'sub_24_dws2.csv']), ignore_index=True)
print(dws2_HeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.107313       -1.095418      0.739966   0.409389
# 1               1       1.115297       -1.082860      0.748984   0.421005
# 2               2       1.137440       -1.075107      0.774079   0.431669
# 3               3       1.170896       -1.075259      0.806977   0.437986
# 4               4       1.210030       -1.080115      0.841941   0.440892
# ...           ...            ...             ...           ...        ...
# 27906        1456      -2.717883       -1.332958     -2.303607  -0.096867
# 27907        1457      -2.675661       -1.316127     -2.168156  -0.113179
# 27908        1458      -2.624580       -1.300916     -2.046566  -0.131785
# 27909        1459      -2.553919       -1.289668     -1.899243  -0.153820
# 27910        1460      -2.477694       -1.283688     -1.738934  -0.174494
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws2_HeightGroup1_df = dws2_HeightGroup1_df.iloc[: , 1:]
dws2_HeightGroup1_df.shape
# Out:
# (27911, 12)

# %%
# Add Class Variable "Activity" in dataframe
dws2_HeightGroup1_df["Activity"] = 'Walking_DownStairs' 
dws2_HeightGroup1_df.shape
# Out:
# (27911, 13)

# %%
# merging all HeightGroup2 csv files from dws_2
dws2_HeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_dws2.csv', 'sub_2_dws2.csv', 'sub_4_dws2.csv', 'sub_6_dws2.csv', 'sub_9_dws2.csv', 'sub_11_dws2.csv', 'sub_13_dws2.csv', 'sub_14_dws2.csv', 'sub_15_dws2.csv', 'sub_16_dws2.csv', 'sub_17_dws2.csv', 'sub_20_dws2.csv', 'sub_22_dws2.csv']), ignore_index=True)
print(dws2_HeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.055270       -0.954541     -0.609278   0.031929
# 1               1       0.034557       -0.942493     -0.606960   0.020308
# 2               2       0.016687       -0.959855     -0.610954   0.009572
# 3               3       0.000695       -1.003050     -0.620385   0.000374
# 4               4      -0.017676       -1.060086     -0.634626  -0.008640
# ...           ...            ...             ...           ...        ...
# 31192        1915       0.821318       -1.002044      0.010088   0.394260
# 31193        1916       0.813559       -0.945642     -0.012615   0.425298
# 31194        1917       0.802957       -0.911150     -0.011541   0.440879
# 31195        1918       0.783794       -0.898710     -0.016435   0.439548
# 31196        1919       0.765903       -0.900199     -0.037666   0.430781
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws2_HeightGroup2_df = dws2_HeightGroup2_df.iloc[: , 1:]
dws2_HeightGroup2_df.shape
# Out:
# (31197, 12)

# %%
# Add Class Variable "Activity" in dataframe
dws2_HeightGroup2_df["Activity"] = 'Walking_DownStairs' 
dws2_HeightGroup2_df.shape
# Out:
# (31197, 13)

# %%
# merging all HeightGroup1 csv files from dws_11
dws11_HeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_3_dws11.csv', 'sub_5_dws11.csv', 'sub_7_dws11.csv', 'sub_8_dws11.csv', 'sub_10_dws11.csv', 'sub_12_dws11.csv', 'sub_18_dws11.csv', 'sub_19_dws11.csv', 'sub_21_dws11.csv', 'sub_23_dws11.csv', 'sub_24_dws11.csv']), ignore_index=True)
print(dws11_HeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.862794       -1.136540     -0.009957   0.319611
# 1               1       0.887555       -1.139740      0.009050   0.324034
# 2               2       0.902975       -1.144646      0.021938   0.324559
# 3               3       0.909755       -1.150267      0.025400   0.322242
# 4               4       0.903041       -1.153462      0.013275   0.318260
# ...           ...            ...             ...           ...        ...
# 10519         434      -2.630665       -0.942106     -2.692480  -0.287566
# 10520         435      -2.622877       -0.941469     -2.686673  -0.291808
# 10521         436      -2.632187       -0.962013     -2.683334  -0.278877
# 10522         437      -2.642530       -1.004807     -2.675556  -0.256651
# 10523         438      -2.644099       -1.077019     -2.663269  -0.226183
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws11_vGroup1_df = dws11_HeightGroup1_df.iloc[: , 1:]
dws11_HeightGroup1_df.shape
# Out:
# (10524, 13)

# %%
# Add Class Variable "Activity" in dataframe
dws11_HeightGroup1_df["Activity"] = 'Walking_DownStairs' 
dws11_HeightGroup1_df.shape
# Out:
# (10524, 14)

# %%
# merging all HeightGroup2 csv files from dws_11
dws11_HeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_dws11.csv', 'sub_2_dws11.csv', 'sub_4_dws11.csv', 'sub_6_dws11.csv', 'sub_9_dws11.csv', 'sub_11_dws11.csv', 'sub_13_dws11.csv', 'sub_14_dws11.csv', 'sub_15_dws11.csv', 'sub_15_dws11.csv', 'sub_16_dws11.csv', 'sub_17_dws11.csv', 'sub_20_dws11.csv', 'sub_22_dws11.csv']), ignore_index=True)
print(dws11_HeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.086504       -1.172129      1.181660   0.033538
# 1               1       0.059454       -1.146609      1.248254   0.024456
# 2               2       0.029339       -1.130040      1.295114   0.012515
# 3               3      -0.004340       -1.119799      1.327633  -0.001892
# 4               4      -0.041066       -1.118417      1.351262  -0.017945
# ...           ...            ...             ...           ...        ...
# 12952         691       1.198224       -1.289482     -2.144893   0.258573
# 12953         692       1.172314       -1.307875     -2.170818   0.239539
# 12954         693       1.113915       -1.319807     -2.233084   0.222888
# 12955         694       1.069544       -1.320696     -2.305056   0.217053
# 12956         695       0.996454       -1.307672     -2.417663   0.218365
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws11_HeightGroup2_df = dws11_HeightGroup2_df.iloc[: , 1:]
dws11_HeightGroup2_df.shape
# Out:
# (12957, 12)

# %%
# Add Class Variable "Activity" in dataframe
dws11_HeightGroup2_df["Activity"] = 'Walking_DownStairs' 
dws11_HeightGroup2_df.shape
# Out:
# (12957, 13)

# %%
# merging all HeightGroup1 csv files from ups_3 
ups3_HeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_3_ups3.csv', 'sub_5_ups3.csv', 'sub_7_ups3.csv', 'sub_8_ups3.csv', 'sub_10_ups3.csv', 'sub_12_ups3.csv', 'sub_18_ups3.csv', 'sub_19_ups3.csv', 'sub_21_ups3.csv', 'sub_23_ups3.csv', 'sub_24_ups3.csv']), ignore_index=True)
print(ups3_HeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.447403       -1.035196     -0.048741   0.220792
# 1               1       0.456338       -1.036821     -0.038044   0.224278
# 2               2       0.465284       -1.046419     -0.017628   0.224639
# 3               3       0.471586       -1.059870      0.010667   0.222144
# 4               4       0.468841       -1.084239      0.024032   0.211277
# ...           ...            ...             ...           ...        ...
# 28886        1392       1.225887       -1.380504     -0.586724   0.178006
# 28887        1393       1.702697       -1.456976     -0.134149   0.112589
# 28888        1394       2.598022       -1.491832      0.750552   0.040798
# 28889        1395      -2.791966       -1.460973      1.655483  -0.037544
# 28890        1396      -2.489767       -1.380595      1.980176  -0.114689
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups3_HeightGroup1_df = ups3_HeightGroup1_df.iloc[: , 1:]
ups3_HeightGroup1_df.shape
# Out:
# (28891, 12)

# %%
# Add Class Variable "Activity" in dataframe
ups3_HeightGroup1_df["Activity"] = 'Walking_UpStairs' 
ups3_HeightGroup1_df.shape
# Out:
# (28891, 13)

# %%
# merging all HeightGroup2 csv files from ups_3
ups3_HeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_ups3.csv', 'sub_2_ups3.csv', 'sub_4_ups3.csv', 'sub_6_ups3.csv', 'sub_9_ups3.csv', 'sub_11_ups3.csv', 'sub_13_ups3.csv', 'sub_14_ups3.csv', 'sub_15_ups3.csv', 'sub_16_ups3.csv', 'sub_17_ups3.csv', 'sub_20_ups3.csv', 'sub_22_ups3.csv']), ignore_index=True)
print(ups3_HeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -2.643769       -1.348560      1.938935  -0.105250
# 1               1      -2.611424       -1.325624      1.946019  -0.122740
# 2               2      -2.544143       -1.316334      2.003067  -0.141604
# 3               3      -2.506960       -1.308531      2.043615  -0.153716
# 4               4      -2.528618       -1.296898      2.026038  -0.155612
# ...           ...            ...             ...           ...        ...
# 29308        2392       0.710971       -1.053417      3.083730   0.322751
# 29309        2393       0.694973       -0.997367      3.094061   0.347397
# 29310        2394       0.681214       -0.941093      3.101978   0.370846
# 29311        2395       0.663800       -0.883853      3.108506   0.390718
# 29312        2396       0.641690       -0.828455      3.115239   0.404623
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups3_HeightGroup2_df = ups3_HeightGroup2_df.iloc[: , 1:]
ups3_HeightGroup2_df.shape
# Out:
# (29313, 12)

# %%
# Add Class Variable "Activity" in dataframe
ups3_HeightGroup2_df["Activity"] = 'Walking_UpStairs' 
ups3_HeightGroup2_df.shape
# Out:
# (29313, 13)

# %%
# merging all HeightGroup1 csv files from ups_4
ups4_HeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_3_ups4.csv', 'sub_5_ups4.csv', 'sub_7_ups4.csv', 'sub_8_ups4.csv', 'sub_10_ups4.csv', 'sub_12_ups4.csv', 'sub_18_ups4.csv', 'sub_19_ups4.csv', 'sub_21_ups4.csv', 'sub_23_ups4.csv', 'sub_24_ups4.csv']), ignore_index=True)
print(ups4_HeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.075400       -1.332123      0.293602   0.207987
# 1               1       1.178555       -1.341586      0.381777   0.209947
# 2               2       1.270955       -1.350223      0.463723   0.209021
# 3               3       1.348542       -1.357631      0.535586   0.206342
# 4               4       1.410781       -1.363649      0.596525   0.203033
# ...           ...            ...             ...           ...        ...
# 34088        1507      -2.208286       -0.734780     -0.350465  -0.596249
# 34089        1508      -2.146088       -0.788391     -0.322954  -0.591508
# 34090        1509      -2.094428       -0.834623     -0.287080  -0.581488
# 34091        1510      -2.071408       -0.876276     -0.254023  -0.561480
# 34092        1511      -2.071189       -0.922735     -0.236846  -0.529632
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups4_HeightGroup1_df = ups4_HeightGroup1_df.iloc[: , 1:]
ups4_HeightGroup1_df.shape
# Out:
# (34093, 12)

# %%
# Add Class Variable "Activity" in dataframe
ups4_HeightGroup1_df["Activity"] = 'Walking_UpStairs' 
ups4_HeightGroup1_df.shape
# Out:
# (34093, 13)

# %%
# merging all HeightGroup2 csv files from ups_4
ups4_HeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_ups4.csv', 'sub_2_ups4.csv', 'sub_4_ups4.csv', 'sub_6_ups4.csv', 'sub_9_ups4.csv', 'sub_11_ups4.csv', 'sub_13_ups4.csv', 'sub_14_ups4.csv', 'sub_15_ups4.csv', 'sub_16_ups4.csv', 'sub_17_ups4.csv', 'sub_20_ups4.csv', 'sub_22_ups4.csv']), ignore_index=True)
print(ups4_HeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.348443       -0.817831      0.539156   0.233475
# 1               1       0.391896       -0.851445      0.553602   0.251660
# 2               2       0.448344       -0.888969      0.574567   0.273181
# 3               3       0.502052       -0.913294      0.588488   0.294097
# 4               4       0.556119       -0.928739      0.603094   0.316126
# ...           ...            ...             ...           ...        ...
# 36974        2705       0.962558       -1.348018     -0.212840   0.181314
# 36975        2706       0.904613       -1.280573     -0.297308   0.224978
# 36976        2707       0.895363       -1.204473     -0.330658   0.279540
# 36977        2708       0.916626       -1.133916     -0.317438   0.335764
# 36978        2709       0.943784       -1.071933     -0.282755   0.387423
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups4_HeightGroup2_df = ups4_HeightGroup2_df.iloc[: , 1:]
ups4_HeightGroup2_df.shape
# Out:
# (36979, 12)

# %%
# Add Class Variable "Activity" in dataframe
ups4_HeightGroup2_df["Activity"] = 'Walking_UpStairs' 
ups4_HeightGroup2_df.shape
# Out:
# (36979, 13)

# %%
# merging all HeightGroup1 csv files from ups_12
ups12_HeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_3_ups12.csv', 'sub_5_ups12.csv', 'sub_7_ups12.csv', 'sub_8_ups12.csv', 'sub_10_ups12.csv', 'sub_12_ups12.csv', 'sub_18_ups12.csv', 'sub_19_ups12.csv', 'sub_21_ups12.csv', 'sub_23_ups12.csv', 'sub_24_ups12.csv']), ignore_index=True)
print(ups12_HeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.278068       -1.207316      1.056729   0.340401
# 1               1       1.307832       -1.215331      1.082388   0.336058
# 2               2       1.352173       -1.226418      1.124696   0.329569
# 3               3       1.397809       -1.242933      1.172005   0.317208
# 4               4       1.431259       -1.261796      1.207751   0.301145
# ...           ...            ...             ...           ...        ...
# 13978         738      -0.476418       -1.215394     -1.091883  -0.159578
# 13979         739      -0.426007       -1.230329     -1.132637  -0.137992
# 13980         740      -0.351505       -1.215819     -1.095573  -0.119672
# 13981         741      -0.329081       -1.205736     -1.106650  -0.115375
# 13982         742      -0.363036       -1.209536     -1.155255  -0.125516
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups12_HeightGroup1_df = ups12_HeightGroup1_df.iloc[: , 1:]
ups12_HeightGroup1_df.shape
# Out:
# (13983, 12)

# %%
# Add Class Variable "Activity" in dataframe
ups12_HeightGroup1_df["Activity"] = 'Walking_UpStairs' 
ups12_HeightGroup1_df.shape
# Out:
# (13983, 13)

# %%
# merging all HeightGroup2 csv files from ups_12
ups12_HeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_ups12.csv', 'sub_2_ups12.csv', 'sub_4_ups12.csv', 'sub_6_ups12.csv', 'sub_9_ups12.csv', 'sub_11_ups12.csv', 'sub_13_ups12.csv', 'sub_14_ups12.csv', 'sub_15_ups12.csv', 'sub_16_ups12.csv', 'sub_17_ups12.csv', 'sub_20_ups12.csv', 'sub_22_ups12.csv']), ignore_index=True)
print(ups12_HeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.838472       -0.901646      0.189667   0.461284
# 1               1       0.901238       -0.900320      0.177763   0.487205
# 2               2       0.993089       -0.914963      0.185652   0.510856
# 3               3       1.029530       -0.921919      0.171090   0.517913
# 4               4       1.052038       -0.927877      0.156188   0.520657
# ...           ...            ...             ...           ...        ...
# 14021        1003      -0.198957       -1.453118      2.183427  -0.023201
# 14022        1004       0.203950       -1.399843      2.576332   0.034453
# 14023        1005       0.420937       -1.351860      2.813387   0.088743
# 14024        1006       0.552714       -1.308184      2.972340   0.136288
# 14025        1007       0.660519       -1.264018      3.092469   0.185274
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups12_HeightGroup2_df = ups12_HeightGroup2_df.iloc[: , 1:]
ups12_HeightGroup2_df.shape
# Out:
# (14026, 12)

# %%
# Add Class Variable "Activity" in dataframe
ups12_HeightGroup2_df["Activity"] = 'Walking_UpStairs' 
ups12_HeightGroup2_df.shape
# Out:
# (14026, 13)

# %% [markdown]
# **Combining all activities of Height frames in a single frame**

# %%
all_activities_HeightGroup1_frame = [wlk7_HeightGroup1_df, wlk8_HeightGroup1_df, wlk15_HeightGroup1_df, std6_HeightGroup1_df, std14_HeightGroup1_df, sit5_HeightGroup1_df, sit13_HeightGroup1_df, jog9_HeightGroup1_df, jog16_HeightGroup1_df, dws1_HeightGroup1_df, dws2_HeightGroup1_df, dws11_HeightGroup1_df, ups3_HeightGroup1_df, ups4_HeightGroup1_df, ups12_HeightGroup1_df]

all_activities_HeightGroup1_df = pd.concat(all_activities_HeightGroup1_frame)
all_activities_HeightGroup1_df.shape
# Out:
# (656564, 14)

# %%
# Shuffle the dataframe rows 
all_activities_HeightGroup1_df.sample(frac=1) 
all_activities_HeightGroup1_df.shape
# Out:
# (656564, 14)

# %%
all_activities_HeightGroup1_df.head()
# Out:
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.959818       -1.462167      1.432332   0.100293   0.994106
# 1       2.011369       -1.456576      1.482870   0.103072   0.993484
# 2       2.075497       -1.449990      1.540119   0.105472   0.992712
# 3       2.126304       -1.446606      1.582288   0.105232   0.992298
# 4       2.208217       -1.441369      1.657403   0.103709   0.991636
#
#    gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0   0.041111       -0.333684       -0.048062        0.127956
# 1   0.048596       -0.380763        0.178926        0.147632
# 2   0.058265       -0.310003        0.427155        0.081579
# 3   0.065318       -0.223194        0.415531       -0.017145
# 4   0.076801       -0.321973        0.308155        0.014350
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z Activity  \
# 0           -0.027966           -0.036617            0.240444  Walking
# ...

# %%
# Delete last column
del all_activities_HeightGroup1_df[all_activities_HeightGroup1_df.columns[-1]]

# %%
all_activities_HeightGroup1_df.head()
# Out:
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.959818       -1.462167      1.432332   0.100293   0.994106
# 1       2.011369       -1.456576      1.482870   0.103072   0.993484
# 2       2.075497       -1.449990      1.540119   0.105472   0.992712
# 3       2.126304       -1.446606      1.582288   0.105232   0.992298
# 4       2.208217       -1.441369      1.657403   0.103709   0.991636
#
#    gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0   0.041111       -0.333684       -0.048062        0.127956
# 1   0.048596       -0.380763        0.178926        0.147632
# 2   0.058265       -0.310003        0.427155        0.081579
# 3   0.065318       -0.223194        0.415531       -0.017145
# 4   0.076801       -0.321973        0.308155        0.014350
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z Activity
# 0           -0.027966           -0.036617            0.240444  Walking
# ...

# %%
# Shuffle the dataframe rows 
all_activities_HeightGroup1_df.sample(frac=1) 
all_activities_HeightGroup1_df.shape
# Out:
# (656564, 13)

# %%
all_activities_HeightGroup1_df.shape
# Out:
# (656564, 13)

# %%
all_activities_HeightGroup2_frames = [wlk7_HeightGroup2_df, wlk8_HeightGroup2_df, wlk15_HeightGroup2_df, std6_HeightGroup2_df, std14_HeightGroup2_df, sit5_HeightGroup2_df, sit13_HeightGroup2_df, jog9_HeightGroup2_df, jog16_HeightGroup2_df, dws1_HeightGroup2_df, dws2_HeightGroup2_df, dws11_HeightGroup2_df, ups3_HeightGroup2_df, ups4_HeightGroup2_df, ups12_HeightGroup2_df]

all_activities_HeightGroup2_df = pd.concat(all_activities_HeightGroup2_frames) 
all_activities_HeightGroup2_df.shape
# Out:
# (752084, 13)

# %%
# Shuffle the dataframe rows 
all_activities_HeightGroup2_df.sample(frac=1) 
all_activities_HeightGroup2_df.shape
# Out:
# (752084, 13)

# %%
all_activities_HeightGroup2_df.head()
# Out:
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0      -1.711140       -1.429168     -2.591433  -0.139767   0.989987
# 1      -1.787917       -1.414171     -2.630956  -0.152324   0.987759
# 2      -1.897323       -1.399331     -2.706668  -0.161610   0.985336
# 3      -2.018375       -1.383279     -2.813421  -0.168058   0.982470
# 4      -2.124395       -1.364054     -2.913092  -0.174613   0.978705
#
#    gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0   0.019745       -0.350593       -0.511691       -0.865217
# 1   0.033602       -0.550553       -2.243217       -0.582409
# 2   0.054729       -0.931014       -1.358033       -0.503947
# 3   0.080680       -1.304668       -0.541368       -0.346302
# 4   0.107922       -1.278349       -0.434722       -0.398598
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z Activity
# 0            0.091702            0.415881            0.093689  Walking
# ...

# %%
all_activities_HeightGroup1_df.isna().sum().sum()
# Out:
# 0

# %%
all_activities_HeightGroup2_df.isna().sum().sum()
# Out:
# 0

# %%
# print(all_activities_HeightGroup1_df) 
# print(all_activities_HeightGroup2_df)

# %% [markdown]
# **Classification**

# %%
# importing libraries 
import numpy as np
from numpy import mean
from numpy import std
from sklearn import metrics
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier 
from xgboost import XGBClassifier 
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# HeightGroupWise classification using five classifiers

# %%
# RF over AgeGroup1 data

# %%
# Preparing Input and Output Splits 
X = all_activities_HeightGroup1_df.iloc[:, :-1].values
y = all_activities_HeightGroup1_df.iloc[:, -1].values

# %%
X.shape, y.shape
# Out:
# ((656564, 12), (656564,))

# %%
# Train Test Splits with a ratio of 70:30 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((459594, 12), (196970, 12), (459594,), (196970,))

# %%
# define the model applying Random Forest 
rf = RandomForestClassifier() 
gnb = GaussianNB() 
lr = LogisticRegression() 
ab = AdaBoostClassifier()
dt = DecisionTreeClassifier()
bagging = BaggingClassifier()
xgb = XGBClassifier() 
lgbm = LGBMClassifier()

# %%
#Train the model using the training sets
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#Predict the response for test dataset 
y_pred = rf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9505457683911256

# %%
#Train the model using the training sets
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#Predict the response for test dataset 
y_pred = gnb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.67624003655379

# %%
#Train the model using the training sets
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Predict the response for test dataset 
y_pred = lr.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5047113773671117

# %%
#Train the model using the training sets
ab.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
#Predict the response for test dataset 
y_pred = ab.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.3905112453673148

# %%
#Train the model using the training sets
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Predict the response for test dataset 
y_pred = dt.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8785551099152155

# %%
#Train the model using the training sets
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
#Predict the response for test dataset 
y_pred = xgb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8007107681372798

# %%
#Train the model using the training sets
lgbm.fit(X_train, y_train)
# Out:
# LGBMClassifier()

# %%
#Predict the response for test dataset 
y_pred = lgbm.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8771944966238513

# %%
#Train the model using the training sets
bagging.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
#Predict the response for test dataset 
y_pred = bagging.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9193075087576789

# %%
# RF over AgeGroup2 data

# %%
# Preparing Input and Output Splits 
X_HeightGroup2 = all_activities_HeightGroup2_df.iloc[:, :-1].values
y_HeightGroup2 = all_activities_HeightGroup2_df.iloc[:, -1].values

# %%
# Train Test Splits with a ratio of 70:30 
X_train, X_test, y_train, y_test = train_test_split(X_HeightGroup2, y_HeightGroup2, test_size = 0.30)

# %%
#Train the model using the training sets
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#Predict the response for test dataset
y_pred = rf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9413675728861035

# %%
#Train the model using the training sets
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#Predict the response for test dataset
y_pred = gnb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7317817981970163

# %%
#Train the model using the training sets
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Predict the response for test dataset
y_pred = lr.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5670490103090956

# %%
#Train the model using the training sets
ab.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
#Predict the response for test dataset
y_pred = ab.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.685439621320238

# %%
#Train the model using the training sets
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Predict the response for test dataset
y_pred = dt.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8697667821970873

# %%
#Train the model using the training sets
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
#Predict the response for test dataset
y_pred = xgb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8697667821970873

# %%
#Train the model using the training sets
lgbm.fit(X_train, y_train)
# Out:
# LGBMClassifier()

# %%
#Predict the response for test dataset
y_pred = lgbm.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8695673370976749

# %%
#Train the model using the training sets
bagging.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
#Predict the response for test dataset
y_pred = bagging.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9138707418471276

# %%
# Training on HeightGroup1 data and testing on HeightGroup2

# %%
# Preparing Input and Output Splits 
X_all_HeightGroup1_train = all_activities_HeightGroup1_df.iloc[:, :-1].values
y_all_HeightGroup1_train = all_activities_HeightGroup1_df.iloc[:, -1].values

# %%
# Preparing Input and Output Splits 
X_all_HeightGroup2_test = all_activities_HeightGroup2_df.iloc[:, :-1].values
y_all_HeightGroup2_test = all_activities_HeightGroup2_df.iloc[:, -1].values

# %%
#Train the model using the training sets
rf.fit(X_all_HeightGroup1_train, y_all_HeightGroup1_train)
# Out:
# RandomForestClassifier()

# %%
#Predict the response for test dataset 
y_pred = rf.predict(X_all_HeightGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_HeightGroup2_test, y_pred))
# Out:
# Accuracy: 0.6984751703267188

# %%
#Train the model using the training sets
gnb.fit(X_all_HeightGroup1_train, y_all_HeightGroup1_train)
# Out:
# GaussianNB()

# %%
#Predict the response for test dataset 
y_pred = gnb.predict(X_all_HeightGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_HeightGroup2_test, y_pred))
# Out:
# Accuracy: 0.6812244376957893

# %%
#Train the model using the training sets
lr.fit(X_all_HeightGroup1_train, y_all_HeightGroup1_train)
# Out:
# LogisticRegression()

# %%
#Predict the response for test dataset 
y_pred = lr.predict(X_all_HeightGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_HeightGroup2_test, y_pred))
# Out:
# Accuracy: 0.5525154105126555

# %%
#Train the model using the training sets
ab.fit(X_all_HeightGroup1_train, y_all_HeightGroup1_train)
# Out:
# AdaBoostClassifier()

# %%
#Predict the response for test dataset 
y_pred = ab.predict(X_all_HeightGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_HeightGroup2_test, y_pred))
# Out:
# Accuracy: 0.38342126677339233

# %%
#Train the model using the training sets
dt.fit(X_all_HeightGroup1_train, y_all_HeightGroup1_train)
# Out:
# DecisionTreeClassifier()

# %%
#Predict the response for test dataset 
y_pred = dt.predict(X_all_HeightGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_HeightGroup2_test, y_pred))
# Out:
# Accuracy: 0.38342126677339233

# %%
#Train the model using the training sets
xgb.fit(X_all_HeightGroup1_train, y_all_HeightGroup1_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
#Predict the response for test dataset 
y_pred = xgb.predict(X_all_HeightGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_HeightGroup2_test, y_pred))
# Out:
# Accuracy: 0.733763781705235

# %%
#Train the model using the training sets
lgbm.fit(X_all_HeightGroup1_train, y_all_HeightGroup1_train)
# Out:
# LGBMClassifier()

# %%
#Predict the response for test dataset 
y_pred = lgbm.predict(X_all_HeightGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_HeightGroup2_test, y_pred))
# Out:
# Accuracy: 0.7303333138319655

# %%
#Train the model using the training sets
bagging.fit(X_all_HeightGroup1_train, y_all_HeightGroup1_train)
# Out:
# BaggingClassifier()

# %%
#Predict the response for test dataset 
y_pred = bagging.predict(X_all_HeightGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_HeightGroup2_test, y_pred))
# Out:
# Accuracy: 0.6526930502443876

# %%
# Training on HeightGroup2 data and testing on HeightGroup1

# %%
# Preparing Input and Output Splits 
X_all_HeightGroup1_test = all_activities_HeightGroup1_df.iloc[:, :-1].values 
y_all_HeightGroup1_test = all_activities_HeightGroup1_df.iloc[:, -1].values

# %%
# Preparing Input and Output Splits 
X_all_HeightGroup2_train = all_activities_HeightGroup2_df.iloc[:, :-1].values
y_all_HeightGroup2_train = all_activities_HeightGroup2_df.iloc[:, -1].values

# %%
#Train the model using the training sets
rf.fit(X_all_HeightGroup2_train, y_all_HeightGroup2_train)
# Out:
# RandomForestClassifier()

# %%
#Predict the response for test dataset 
y_pred = rf.predict(X_all_HeightGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_HeightGroup1_test, y_pred))
# Out:
# Accuracy: 0.6506814263346756

# %%
#Train the model using the training sets
gnb.fit(X_all_HeightGroup2_train, y_all_HeightGroup2_train)
# Out:
# GaussianNB()

# %%
#Predict the response for test dataset 
y_pred = gnb.predict(X_all_HeightGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_HeightGroup1_test, y_pred))
# Out:
# Accuracy: 0.6616948233530928

# %%
#Train the model using the training sets
lr.fit(X_all_HeightGroup2_train, y_all_HeightGroup2_train)
# Out:
# LogisticRegression()

# %%
#Predict the response for test dataset 
y_pred = lr.predict(X_all_HeightGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_HeightGroup1_test, y_pred))
# Out:
# Accuracy: 0.5082429131051961

# %%
#Train the model using the training sets
ab.fit(X_all_HeightGroup2_train, y_all_HeightGroup2_train)
# Out:
# AdaBoostClassifier()

# %%
#Predict the response for test dataset 
y_pred = ab.predict(X_all_HeightGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_HeightGroup1_test, y_pred))
# Out:
# Accuracy: 0.6321912258363237

# %%
#Train the model using the training sets
dt.fit(X_all_HeightGroup2_train, y_all_HeightGroup2_train)
# Out:
# DecisionTreeClassifier()

# %%
#Predict the response for test dataset 
y_pred = dt.predict(X_all_HeightGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_HeightGroup1_test, y_pred))
# Out:
# Accuracy: 0.5573546524025076

# %%
#Train the model using the training sets
xgb.fit(X_all_HeightGroup2_train, y_all_HeightGroup2_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
#Predict the response for test dataset 
y_pred = xgb.predict(X_all_HeightGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_HeightGroup1_test, y_pred))
# Out:
# Accuracy: 0.6908161275976142

# %%
#Train the model using the training sets
lgbm.fit(X_all_HeightGroup2_train, y_all_HeightGroup2_train)
# Out:
# LGBMClassifier()

# %%
#Predict the response for test dataset 
y_pred = lgbm.predict(X_all_HeightGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_HeightGroup1_test, y_pred))
# Out:
# Accuracy: 0.6809008718114304

# %%
#Train the model using the training sets
bagging.fit(X_all_HeightGroup2_train, y_all_HeightGroup2_train)
# Out:
# BaggingClassifier()

# %%
#Predict the response for test dataset 
y_pred = bagging.predict(X_all_HeightGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_HeightGroup1_test, y_pred))
# Out:
# Accuracy: 0.6003542685861546

# %%
# Combining data of all activities and both groups

# %%
both_group_frame = [all_activities_HeightGroup1_df, all_activities_HeightGroup2_df] 

all_activities_both_HeightGroup_df = pd.concat(both_group_frame) 
all_activities_both_HeightGroup_df.shape
# Out:
# (1408648, 13)

# %%
# Shuffle the dataframe rows 
all_activities_both_HeightGroup_df.sample(frac=1) 
all_activities_both_HeightGroup_df.shape
# Out:
# (1408648, 13)

# %%
X = all_activities_both_HeightGroup_df.iloc[:, :-1].values 
y = all_activities_both_HeightGroup_df.iloc[:, -1].values

# %%
X.shape, y.shape
# Out:
# ((1408648, 12), (1408648,))

# %%
# Train Test Splits with a ratio of 70:30 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %%
#Train the model using the training sets
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#Predict the response for test dataset 
y_pred = rf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9317644553295709

# %%
#Train the model using the training sets
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#Predict the response for test dataset 
y_pred = gnb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.726156248890782

# %%
#Train the model using the training sets
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Predict the response for test dataset 
y_pred = lr.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5412581786343899

# %%
#Train the model using the training sets
ab.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
#Predict the response for test dataset 
y_pred = ab.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6891326210674523

# %%
#Train the model using the training sets
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Predict the response for test dataset 
y_pred = dt.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.85479004720832

# %%
#Train the model using training sets
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
#Predict the response for test dataset 
y_pred = xgb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7808469101622121

# %%
#Train the model using the training sets
lgbm.fit(X_train, y_train)
# Out:
# LGBMClassifier()

# %%
#Predict the response for test dataset 
y_pred = lgbm.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8418959050627669

# %%
#Train the model using the training sets
bagging.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
#Predict the response for test dataset 
y_pred = bagging.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9006495580875307
