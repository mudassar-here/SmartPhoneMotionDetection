# %%
import pandas as pd
import glob

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-45c24dfd-7618-4dc0-bc47-b87dfda12d1b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45c24dfd-7618-4dc0-bc47-b87dfda12d1b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sub_1.csv to sub_1.csv
# Saving sub_1_dws1.csv to sub_1_dws1.csv
# Saving sub_1_dws2.csv to sub_1_dws2.csv
# Saving sub_1_dws11.csv to sub_1_dws11.csv
# Saving sub_1_jog9.csv to sub_1_jog9.csv
# Saving sub_1_jog16.csv to sub_1_jog16.csv
# Saving sub_1_sit5.csv to sub_1_sit5.csv
# Saving sub_1_sit13.csv to sub_1_sit13.csv
# Saving sub_1_std6.csv to sub_1_std6.csv
# Saving sub_1_std14.csv to sub_1_std14.csv
# Saving sub_1_ups3.csv to sub_1_ups3.csv
# Saving sub_1_ups4.csv to sub_1_ups4.csv
# Saving sub_1_ups12.csv to sub_1_ups12.csv
# ...

# %%
# merging all male csv files from wlk_7
wlk7_AgeGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_2.csv', 'sub_3.csv', 'sub_5.csv', 'sub_6.csv', 'sub_7.csv', 'sub_8.csv', 'sub_11.csv', 'sub_16.csv', 'sub_17.csv', 'sub_18.csv', 'sub_19.csv', 'sub_20.csv', 'sub_21.csv', 'sub_23.csv', 'sub_24.csv']), ignore_index=True)
print(wlk7_AgeGroup1_df)
# Out:
#         Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0                0       1.306530       -1.118072      0.739332   0.422231
# 1                1       1.423767       -1.116880      0.839693   0.433757
# 2                2       1.518297       -1.115365      0.934253   0.439243
# 3                3       1.594993       -1.110211      1.010802   0.444342
# 4                4       1.655634       -1.102925      1.080309   0.449365
# ...            ...            ...             ...           ...        ...
# 100875        5016       1.456354        0.025356      2.896466   0.993139
# 100876        5017       1.435872       -0.007495      2.934749   0.990884
# 100877        5018       1.438846       -0.054606      2.985588   0.989830
# 100878        5019       1.454454       -0.112258      3.026277   0.986988
# 100879        5020       1.437505       -0.167232      3.047170   0.977303
#
# ...

# %%
# Drop first column of dataframe
wlk7_AgeGroup1_df = wlk7_AgeGroup1_df.iloc[: , 1:]
wlk7_AgeGroup1_df.shape
# Out:
# (100880, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk7_AgeGroup1_df["Activity"] = 'Walking' 
print(wlk7_AgeGroup1_df)
# Out:
#         attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0            1.306530       -1.118072      0.739332   0.422231   0.899259
# 1            1.423767       -1.116880      0.839693   0.433757   0.898737
# 2            1.518297       -1.115365      0.934253   0.439243   0.898072
# 3            1.594993       -1.110211      1.010802   0.444342   0.895792
# 4            1.655634       -1.102925      1.080309   0.449365   0.892530
# ...               ...             ...           ...        ...        ...
# 100875       1.456354        0.025356      2.896466   0.993139  -0.025353
# 100876       1.435872       -0.007495      2.934749   0.990884   0.007495
# 100877       1.438846       -0.054606      2.985588   0.989830   0.054579
# 100878       1.454454       -0.112258      3.026277   0.986988   0.112022
# 100879       1.437505       -0.167232      3.047170   0.977303   0.166454
#
#         gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# merging all male csv files from wlk_7
wlk7_AgeGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1.csv', 'sub_4.csv', 'sub_9.csv', 'sub_10.csv', 'sub_12.csv', 'sub_13.csv', 'sub_14.csv', 'sub_15.csv', 'sub_22.csv']), ignore_index=True)
print(wlk7_AgeGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -1.711140       -1.429168     -2.591433  -0.139767
# 1               1      -1.787917       -1.414171     -2.630956  -0.152324
# 2               2      -1.897323       -1.399331     -2.706668  -0.161610
# 3               3      -2.018375       -1.383279     -2.813421  -0.168058
# 4               4      -2.124395       -1.364054     -2.913092  -0.174613
# ...           ...            ...             ...           ...        ...
# 57760        6437       0.820939       -1.010720     -0.679626   0.388757
# 57761        6438       0.812806       -0.966541     -0.656513   0.412596
# 57762        6439       0.803715       -0.939513     -0.626011   0.424890
# 57763        6440       0.783811       -0.914628     -0.599212   0.430707
# 57764        6441       0.758766       -0.895560     -0.577389   0.430069
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
wlk7_AgeGroup2_df = wlk7_AgeGroup2_df.iloc[: , 1:]
wlk7_AgeGroup2_df.shape
# Out:
# (57765, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk7_AgeGroup2_df["Activity"] = 'Walking' 
print(wlk7_AgeGroup2_df)
# Out:
#        attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0          -1.711140       -1.429168     -2.591433  -0.139767   0.989987
# 1          -1.787917       -1.414171     -2.630956  -0.152324   0.987759
# 2          -1.897323       -1.399331     -2.706668  -0.161610   0.985336
# 3          -2.018375       -1.383279     -2.813421  -0.168058   0.982470
# 4          -2.124395       -1.364054     -2.913092  -0.174613   0.978705
# ...              ...             ...           ...        ...        ...
# 57760       0.820939       -1.010720     -0.679626   0.388757   0.847214
# 57761       0.812806       -0.966541     -0.656513   0.412596   0.822926
# 57762       0.803715       -0.939513     -0.626011   0.424890   0.807271
# 57763       0.783811       -0.914628     -0.599212   0.430707   0.792336
# 57764       0.758766       -0.895560     -0.577389   0.430069   0.780560
#
#        gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# merging all male csv files from wlk_8
wlk8_AgeGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_2_w8.csv', 'sub_3_w8.csv', 'sub_5_w8.csv', 'sub_6_w8.csv', 'sub_7_w8.csv', 'sub_8_w8.csv', 'sub_11_w8.csv', 'sub_16_w8.csv', 'sub_17_w8.csv', 'sub_18_w8.csv', 'sub_19_w8.csv', 'sub_20_w8.csv', 'sub_21_w8.csv', 'sub_23_w8.csv', 'sub_24_w8.csv']), ignore_index=True)
print(wlk8_AgeGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.310373       -1.309689      1.442206   0.249436
# 1               1       1.097026       -1.295214      1.256769   0.242127
# 2               2       0.917966       -1.265394      1.100944   0.238842
# 3               3       0.777748       -1.234542      0.972128   0.231515
# 4               4       0.661369       -1.202601      0.858087   0.221066
# ...           ...            ...             ...           ...        ...
# 76634        4071       0.732151       -1.023012     -2.798738   0.348138
# 76635        4072       0.719940       -0.958009     -2.811475   0.379219
# 76636        4073       0.738723       -0.946121     -2.745565   0.393794
# 76637        4074       0.722347       -0.976487     -2.779944   0.370201
# 76638        4075       0.700401       -0.988938     -2.833834   0.354216
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
wlk8_AgeGroup1_df = wlk8_AgeGroup1_df.iloc[: , 1:]
wlk8_AgeGroup1_df.shape
# Out:
# (76639, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk8_AgeGroup1_df["Activity"] = 'Walking' 
print(wlk8_AgeGroup1_df)
# Out:
#        attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0           1.310373       -1.309689      1.442206   0.249436   0.966105
# 1           1.097026       -1.295214      1.256769   0.242127   0.962267
# 2           0.917966       -1.265394      1.100944   0.238842   0.953726
# 3           0.777748       -1.234542      0.972128   0.231515   0.943997
# 4           0.661369       -1.202601      0.858087   0.221066   0.932978
# ...              ...             ...           ...        ...        ...
# 76634       0.732151       -1.023012     -2.798738   0.348138   0.853681
# 76635       0.719940       -0.958009     -2.811475   0.379219   0.818048
# 76636       0.738723       -0.946121     -2.745565   0.393794   0.811153
# 76637       0.722347       -0.976487     -2.779944   0.370201   0.828535
# 76638       0.700401       -0.988938     -2.833834   0.354216   0.835443
#
#        gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# merging all male csv files from wlk_8
wlk8_AgeGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_w8.csv', 'sub_4_w8.csv', 'sub_9_w8.csv', 'sub_10_w8.csv', 'sub_12_w8.csv', 'sub_13_w8.csv', 'sub_14_w8.csv', 'sub_15_w8.csv', 'sub_22_w8.csv']), ignore_index=True)
print(wlk8_AgeGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       2.255404       -1.421448      1.482931   0.115265
# 1               1       1.960381       -1.423633      1.195886   0.135644
# 2               2       1.648809       -1.412348      0.888191   0.157306
# 3               3       1.342174       -1.388827      0.616273   0.176258
# 4               4       1.121672       -1.355100      0.449400   0.192801
# ...           ...            ...             ...           ...        ...
# 43727        4943       0.941090       -1.092168      0.900210   0.372226
# 43728        4944       0.929729       -1.126047      0.878770   0.344811
# 43729        4945       0.927453       -1.159592      0.877930   0.319807
# 43730        4946       0.961754       -1.195810      0.910480   0.300404
# 43731        4947       1.041013       -1.233225      0.977956   0.285793
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
wlk8_AgeGroup2_df = wlk8_AgeGroup2_df.iloc[: , 1:]
wlk8_AgeGroup2_df.shape
# Out:
# (43732, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk8_AgeGroup2_df["Activity"] = 'Walking' 
wlk8_AgeGroup2_df.shape
# Out:
# (43732, 13)

# %%
# merging all male csv files from wlk_15
wlk15_AgeGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_2_wlk15.csv', 'sub_3_wlk15.csv', 'sub_5_wlk15.csv', 'sub_6_wlk15.csv', 'sub_7_wlk15.csv', 'sub_8_wlk15.csv', 'sub_11_wlk15.csv', 'sub_16_wlk15.csv', 'sub_17_wlk15.csv', 'sub_18_wlk15.csv', 'sub_19_wlk15.csv', 'sub_20_wlk15.csv', 'sub_21_wlk15.csv', 'sub_23_wlk15.csv', 'sub_24_wlk15.csv']), ignore_index=True)
print(wlk15_AgeGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       2.154447       -1.188441      1.659468   0.311341
# 1               1       2.183331       -1.198280      1.692800   0.297790
# 2               2       2.202893       -1.204004      1.709669   0.289334
# 3               3       2.205051       -1.205948      1.706714   0.287413
# 4               4       2.180659       -1.204439      1.689016   0.293639
# ...           ...            ...             ...           ...        ...
# 43990        2055      -1.287175       -1.180782      1.184133  -0.365012
# 43991        2056      -1.217304       -1.160821      1.208497  -0.373942
# 43992        2057      -1.083201       -1.167077      1.269294  -0.347061
# 43993        2058      -0.966096       -1.193223      1.348783  -0.303291
# 43994        2059      -0.989568       -1.205294      1.358403  -0.298726
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
wlk15_AgeGroup1_df = wlk15_AgeGroup1_df.iloc[: , 1:]
wlk15_AgeGroup1_df.shape
# Out:
# (43995, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk15_AgeGroup1_df["Activity"] = 'Walking' 
wlk15_AgeGroup1_df.shape
# Out:
# (43995, 13)

# %%
# merging all male csv files from wlk_15
wlk15_AgeGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_wlk15.csv', 'sub_4_wlk15.csv', 'sub_9_wlk15.csv', 'sub_10_wlk15.csv', 'sub_12_wlk15.csv', 'sub_13_wlk15.csv', 'sub_14_wlk15.csv', 'sub_15_wlk15.csv', 'sub_22_wlk15.csv']), ignore_index=True)
print(wlk15_AgeGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -0.642341       -1.408409     -1.725791  -0.096855
# 1               1      -1.063803       -1.440007     -2.200242  -0.114011
# 2               2      -1.258381       -1.432875     -2.424099  -0.130829
# 3               3      -1.391648       -1.420133     -2.584396  -0.147692
# 4               4      -1.602210       -1.412241     -2.812153  -0.157814
# ...           ...            ...             ...           ...        ...
# 21272        2368       0.652484       -0.807196      0.146552   0.419865
# 21273        2369       0.622831       -0.843409      0.138808   0.387870
# 21274        2370       0.617302       -0.846571      0.128739   0.383509
# 21275        2371       0.645521       -0.830476      0.144746   0.405800
# 21276        2372       0.660655       -0.824494      0.171551   0.416610
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
wlk15_AgeGroup2_df = wlk15_AgeGroup2_df.iloc[: , 1:]
wlk15_AgeGroup2_df.shape
# Out:
# (21277, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk15_AgeGroup2_df["Activity"] = 'Walking' 
wlk15_AgeGroup2_df.shape
# Out:
# (21277, 13)

# %%
# merging all male csv files from std_6
std6_AgeGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_2_std6.csv', 'sub_3_std6.csv', 'sub_5_std6.csv', 'sub_6_std6.csv', 'sub_7_std6.csv', 'sub_8_std6.csv', 'sub_11_std6.csv', 'sub_16_std6.csv', 'sub_17_std6.csv', 'sub_18_std6.csv', 'sub_19_std6.csv', 'sub_20_std6.csv', 'sub_21_std6.csv', 'sub_23_std6.csv', 'sub_24_std6.csv']), ignore_index=True)
print(std6_AgeGroup1_df)
# Out:
#         Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0                0       1.830732       -1.377221      1.975182   0.185901
# 1                1       1.821837       -1.377558      1.964111   0.186014
# 2                2       1.814944       -1.378646      1.954566   0.185302
# 3                3       1.814076       -1.379773      1.951624   0.184267
# 4                4       1.819682       -1.380500      1.955264   0.183313
# ...            ...            ...             ...           ...        ...
# 145546       10968       0.024580       -1.445235     -1.865114   0.003078
# 145547       10969       0.035625       -1.444928     -1.845826   0.004471
# 145548       10970       0.047078       -1.444934     -1.826624   0.005908
# 145549       10971       0.058243       -1.445177     -1.808854   0.007293
# 145550       10972       0.068046       -1.445550     -1.793355   0.008494
#
# ...

# %%
# Drop first column of dataframe
std6_AgeGroup1_df = std6_AgeGroup1_df.iloc[: , 1:]
std6_AgeGroup1_df.shape
# Out:
# (145551, 12)

# %%
# Add Class Variable "Activity" in dataframe
std6_AgeGroup1_df["Activity"] = 'Standing' 
std6_AgeGroup1_df.shape
# Out:
# (145551, 13)

# %%
# merging all male csv files from std_6
std6_AgeGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_std6.csv', 'sub_4_std6.csv', 'sub_9_std6.csv', 'sub_10_std6.csv', 'sub_12_std6.csv', 'sub_13_std6.csv', 'sub_14_std6.csv', 'sub_15_std6.csv', 'sub_22_std6.csv']), ignore_index=True)
print(std6_AgeGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       2.489271       -1.397067      1.899690   0.104929
# 1               1       2.488154       -1.396068      1.905025   0.105682
# 2               2       2.489687       -1.394939      1.912298   0.106144
# 3               3       2.494505       -1.393874      1.922063   0.106105
# 4               4       2.500577       -1.393094      1.931172   0.105709
# ...           ...            ...             ...           ...        ...
# 79260        7622      -1.197682       -1.477199     -1.878977  -0.086168
# 79261        7623      -1.272631       -1.480059     -1.949962  -0.085695
# 79262        7624      -1.347158       -1.483424     -2.019999  -0.084103
# 79263        7625      -1.416108       -1.486702     -2.084729  -0.081949
# 79264        7626      -1.480307       -1.489345     -2.145587  -0.079933
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe 
std6_AgeGroup2_df = std6_AgeGroup2_df.iloc[: , 1:]
std6_AgeGroup2_df.shape
# Out:
# (79265, 12)

# %%
# Add Class Variable "Activity" in dataframe
std6_AgeGroup2_df["Activity"] = 'Standing' 
std6_AgeGroup2_df.shape
# Out:
# (79265, 13)

# %%
# merging all male csv files from std_14
std14_AgeGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_2_std14.csv', 'sub_3_std14.csv', 'sub_5_std14.csv', 'sub_6_std14.csv', 'sub_7_std14.csv', 'sub_8_std14.csv', 'sub_11_std14.csv', 'sub_16_std14.csv', 'sub_17_std14.csv', 'sub_18_std14.csv', 'sub_19_std14.csv', 'sub_20_std14.csv', 'sub_21_std14.csv', 'sub_23_std14.csv', 'sub_24_std14.csv']), ignore_index=True)
print(std14_AgeGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.622390       -1.260485      1.275449   0.304943
# 1               1       1.620846       -1.260411      1.273035   0.305037
# 2               2       1.619486       -1.260364      1.270624   0.305103
# 3               3       1.618485       -1.260332      1.268429   0.305148
# 4               4       1.617682       -1.260307      1.266625   0.305184
# ...           ...            ...             ...           ...        ...
# 51257        3964      -2.512274       -1.475547      0.560892  -0.055978
# 51258        3965      -2.514569       -1.474699      0.558068  -0.056297
# 51259        3966      -2.517105       -1.473640      0.555248  -0.056716
# 51260        3967      -2.515195       -1.472593      0.557282  -0.057477
# 51261        3968      -2.512655       -1.471566      0.560290  -0.058280
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
std14_AgeGroup1_df = std14_AgeGroup1_df.iloc[: , 1:]
std14_AgeGroup1_df.shape
# Out:
# (51262, 12)

# %%
# Add Class Variable "Activity" in dataframe
std14_AgeGroup1_df["Activity"] = 'Standing' 
std14_AgeGroup1_df.shape
# Out:
# (51262, 13)

# %%
# merging all male csv files from std_14
std14_AgeGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_std14.csv', 'sub_4_std14.csv', 'sub_9_std14.csv', 'sub_10_std14.csv', 'sub_12_std14.csv', 'sub_13_std14.csv', 'sub_14_std14.csv', 'sub_15_std14.csv', 'sub_22_std14.csv']), ignore_index=True)
print(std14_AgeGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.573929       -1.051363      1.611548   0.496386
# 1               1       1.573086       -1.051097      1.611145   0.496618
# 2               2       1.574466       -1.050255      1.612825   0.497346
# 3               3       1.574735       -1.053220      1.614236   0.494771
# 4               4       1.577461       -1.054274      1.618206   0.493848
# ...           ...            ...             ...           ...        ...
# 30344        5774      -0.619835       -1.350551      2.879654  -0.126790
# 30345        5775      -0.619461       -1.350649      2.877945  -0.126668
# 30346        5776      -0.619264       -1.350392      2.876637  -0.126779
# 30347        5777      -0.619338       -1.349851      2.875683  -0.127099
# 30348        5778      -0.619668       -1.349268      2.874892  -0.127489
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe 
std14_AgeGroup2_df = std14_AgeGroup2_df.iloc[: , 1:]
std14_AgeGroup2_df.shape
# Out:
# (30349, 12)

# %%
# Add Class Variable "Activity" in dataframe
std14_AgeGroup2_df["Activity"] = 'Standing' 
std14_AgeGroup2_df.shape
# Out:
# (30349, 13)

# %%
# merging all male csv files from sit_5
sit5_AgeGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_2_sit5.csv', 'sub_3_sit5.csv', 'sub_5_sit5.csv', 'sub_6_sit5.csv', 'sub_7_sit5.csv', 'sub_8_sit5.csv', 'sub_11_sit5.csv', 'sub_16_sit5.csv', 'sub_17_sit5.csv', 'sub_18_sit5.csv', 'sub_19_sit5.csv', 'sub_20_sit5.csv', 'sub_21_sit5.csv', 'sub_23_sit5.csv', 'sub_24_sit5.csv']), ignore_index=True)
print(sit5_AgeGroup1_df)
# Out:
#         Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0                0       0.078285       -0.118930     -0.168362   0.077653
# 1                1       0.078188       -0.119013     -0.168719   0.077556
# 2                2       0.078171       -0.119131     -0.169011   0.077538
# 3                3       0.078180       -0.119220     -0.169191   0.077546
# 4                4       0.078190       -0.119255     -0.169255   0.077555
# ...            ...            ...             ...           ...        ...
# 145745       10683      -2.563484       -0.149645     -0.322130  -0.540334
# 145746       10684      -2.559251       -0.157457     -0.316592  -0.543177
# 145747       10685      -2.554478       -0.161579     -0.309695  -0.546746
# 145748       10686      -2.549122       -0.163005     -0.302709  -0.551010
# 145749       10687      -2.542947       -0.165970     -0.295609  -0.555781
#
# ...

# %%
# Drop first column of dataframe
sit5_AgeGroup1_df = sit5_AgeGroup1_df.iloc[: , 1:]
sit5_AgeGroup1_df.shape
# Out:
# (145750, 12)

# %%
# Add Class Variable "Activity" in dataframe
sit5_AgeGroup1_df["Activity"] = 'Sitting' 
sit5_AgeGroup1_df.shape
# Out:
# (145750, 13)

# %%
# merging all male csv files from sit_5
sit5_AgeGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_sit5.csv', 'sub_4_sit5.csv', 'sub_9_sit5.csv', 'sub_10_sit5.csv', 'sub_12_sit5.csv', 'sub_13_sit5.csv', 'sub_14_sit5.csv', 'sub_15_sit5.csv', 'sub_22_sit5.csv']), ignore_index=True)
print(sit5_AgeGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.351138       -0.416302     -0.098023   0.314588
# 1               1       0.351219       -0.416372     -0.098025   0.314649
# 2               2       0.351145       -0.416497     -0.098045   0.314567
# 3               3       0.350849       -0.416695     -0.098148   0.314286
# 4               4       0.350859       -0.416863     -0.098022   0.314271
# ...           ...            ...             ...           ...        ...
# 88902        8461       0.414219       -0.237713      1.090686   0.391157
# 88903        8462       0.414810       -0.237391      1.089693   0.391714
# 88904        8463       0.415104       -0.237104      1.088961   0.392002
# 88905        8464       0.415130       -0.236966      1.088600   0.392038
# 88906        8465       0.414942       -0.236914      1.088706   0.391876
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
sit5_AgeGroup2_df = sit5_AgeGroup2_df.iloc[: , 1:]
sit5_AgeGroup2_df.shape
# Out:
# (88907, 12)

# %%
# Add Class Variable "Activity" in dataframe
sit5_AgeGroup2_df["Activity"] = 'Sitting' 
sit5_AgeGroup2_df.shape
# Out:
# (88907, 13)

# %%
# merging all male csv files from sit_13
sit13_AgeGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_2_sit13.csv', 'sub_3_sit13.csv', 'sub_5_sit13.csv', 'sub_6_sit13.csv', 'sub_7_sit13.csv', 'sub_8_sit13.csv', 'sub_11_sit13.csv', 'sub_16_sit13.csv', 'sub_17_sit13.csv', 'sub_18_sit13.csv', 'sub_19_sit13.csv', 'sub_20_sit13.csv', 'sub_21_sit13.csv', 'sub_23_sit13.csv', 'sub_24_sit13.csv']), ignore_index=True)
print(sit13_AgeGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.174049       -0.178345      0.001524   0.170425
# 1               1       0.173654       -0.178096      0.001367   0.170050
# 2               2       0.173256       -0.177895      0.001229   0.169670
# 3               3       0.172880       -0.177789      0.001058   0.169308
# 4               4       0.172597       -0.177737      0.000809   0.169035
# ...           ...            ...             ...           ...        ...
# 61138        3381      -2.368280       -0.381075     -0.089417  -0.648402
# 61139        3382      -2.368752       -0.381071     -0.089478  -0.648090
# 61140        3383      -2.369130       -0.381163     -0.089465  -0.647814
# 61141        3384      -2.369372       -0.381295     -0.089468  -0.647619
# 61142        3385      -2.369404       -0.381297     -0.089545  -0.647598
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
sit13_AgeGroup1_df = sit13_AgeGroup1_df.iloc[: , 1:]
sit13_AgeGroup1_df.shape
# Out:
# (61143, 12)

# %%
# Add Class Variable "Activity" in dataframe
sit13_AgeGroup1_df["Activity"] = 'Sitting' 
sit13_AgeGroup1_df.shape
# Out:
# (61143, 13)

# %%
# merging all male csv files from sit_13
sit13_AgeGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_sit13.csv', 'sub_4_sit13.csv', 'sub_9_sit13.csv', 'sub_10_sit13.csv', 'sub_12_sit13.csv', 'sub_13_sit13.csv', 'sub_14_sit13.csv', 'sub_15_sit13.csv', 'sub_22_sit13.csv']), ignore_index=True)
print(sit13_AgeGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.351138       -0.416302     -0.098023   0.314588
# 1               1       0.351219       -0.416372     -0.098025   0.314649
# 2               2       0.351145       -0.416497     -0.098045   0.314567
# 3               3       0.350849       -0.416695     -0.098148   0.314286
# 4               4       0.350859       -0.416863     -0.098022   0.314271
# ...           ...            ...             ...           ...        ...
# 42973        3552       0.449772        0.012088      0.112036   0.434728
# 42974        3553       0.449075        0.013243      0.111479   0.434094
# 42975        3554       0.448561        0.014333      0.110953   0.433625
# 42976        3555       0.447085        0.015270      0.110621   0.432288
# 42977        3556       0.445072        0.015881      0.110639   0.430468
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
sit13_AgeGroup2_df = sit13_AgeGroup2_df.iloc[: , 1:]
sit13_AgeGroup2_df.shape
# Out:
# (42978, 12)

# %%
# Add Class Variable "Activity" in dataframe
sit13_AgeGroup2_df["Activity"] = 'Sitting' 
sit13_AgeGroup2_df.shape
# Out:
# (42978, 13)

# %%
# merging all male csv files from jog_9
jog9_AgeGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_2_jog9.csv', 'sub_3_jog9.csv', 'sub_5_jog9.csv', 'sub_6_jog9.csv', 'sub_7_jog9.csv', 'sub_8_jog9.csv', 'sub_11_jog9.csv', 'sub_16_jog9.csv', 'sub_17_jog9.csv', 'sub_18_jog9.csv', 'sub_19_jog9.csv', 'sub_20_jog9.csv', 'sub_21_jog9.csv', 'sub_23_jog9.csv', 'sub_24_jog9.csv']), ignore_index=True)
print(jog9_AgeGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.234430       -1.036062      0.530732   0.481051
# 1               1       1.375040       -1.073858      0.628769   0.467628
# 2               2       1.484318       -1.098037      0.749249   0.453640
# 3               3       1.581581       -1.103802      0.911256   0.450174
# 4               4       1.654712       -1.108717      1.050088   0.444238
# ...           ...            ...             ...           ...        ...
# 65292        2838      -1.017175       -1.162354     -1.310722  -0.337852
# 65293        2839      -1.292318       -1.078857     -1.562349  -0.454140
# 65294        2840      -1.403760       -0.951444     -1.709745  -0.572428
# 65295        2841      -1.504000       -0.843886     -1.828078  -0.663082
# 65296        2842      -1.550190       -0.746814     -1.889135  -0.733701
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
jog9_AgeGroup1_df = jog9_AgeGroup1_df.iloc[: , 1:]
jog9_AgeGroup1_df.shape
# Out:
# (65297, 12)

# %%
# Add Class Variable "Activity" in dataframe
jog9_AgeGroup1_df["Activity"] = 'Jogging' 
jog9_AgeGroup1_df.shape
# Out:
# (65297, 13)

# %%
# merging all male csv files from jog_9
jog9_AgeGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_jog9.csv', 'sub_4_jog9.csv', 'sub_9_jog9.csv', 'sub_10_jog9.csv', 'sub_12_jog9.csv', 'sub_13_jog9.csv', 'sub_14_jog9.csv', 'sub_15_jog9.csv', 'sub_22_jog9.csv']), ignore_index=True)
print(jog9_AgeGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       3.058304       -1.227988      2.570999   0.027964
# 1               1       3.075964       -1.225818      2.615277   0.022178
# 2               2       3.103364       -1.235013      2.651791   0.012594
# 3               3       3.109208       -1.244901      2.678484   0.010366
# 4               4       3.074214       -1.263514      2.661371   0.020364
# ...           ...            ...             ...           ...        ...
# 39025        4808       1.009935       -1.168745     -2.709150   0.331332
# 39026        4809       1.029138       -1.194641     -2.717922   0.314736
# 39027        4810       1.011173       -1.238663     -2.711134   0.276290
# 39028        4811       1.046748       -1.275486     -2.665642   0.251943
# 39029        4812       1.111508       -1.308082     -2.611691   0.232745
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
jog9_AgeGroup2_df = jog9_AgeGroup2_df.iloc[: , 1:]
jog9_AgeGroup2_df.shape
# Out:
# (39030, 12)

# %%
# Add Class Variable "Activity" in dataframe
jog9_AgeGroup2_df["Activity"] = 'Jogging' 
jog9_AgeGroup2_df.shape
# Out:
# (39030, 13)

# %%
# merging all male csv files from jog_16
jog16_AgeGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_2_jog16.csv', 'sub_3_jog16.csv', 'sub_5_jog16.csv', 'sub_6_jog16.csv', 'sub_7_jog16.csv', 'sub_8_jog16.csv', 'sub_11_jog16.csv', 'sub_16_jog16.csv', 'sub_17_jog16.csv', 'sub_18_jog16.csv', 'sub_19_jog16.csv', 'sub_20_jog16.csv', 'sub_21_jog16.csv', 'sub_23_jog16.csv', 'sub_24_jog16.csv']), ignore_index=True)
print(jog16_AgeGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.683416       -1.309282      1.183437   0.256888
# 1               1       1.429139       -1.281262      1.005889   0.282632
# 2               2       1.203411       -1.236084      0.851848   0.306565
# 3               3       1.050246       -1.172212      0.725235   0.336698
# 4               4       0.925612       -1.101603      0.597556   0.361271
# ...           ...            ...             ...           ...        ...
# 18730         785      -1.553643       -1.207026     -2.015848  -0.355748
# 18731         786      -1.533934       -1.243476     -2.010537  -0.321289
# 18732         787      -1.301587       -1.362634     -1.783378  -0.199218
# 18733         788      -0.524913       -1.486641     -0.952944  -0.042124
# 18734         789       0.683482       -1.435057      0.377682   0.085456
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
jog16_AgeGroup1_df = jog16_AgeGroup1_df.iloc[: , 1:]
jog16_AgeGroup1_df.shape
# Out:
# (18735, 12)

# %%
# Add Class Variable "Activity" in dataframe
jog16_AgeGroup1_df["Activity"] = 'Jogging' 
jog16_AgeGroup1_df.shape
# Out:
# (18735, 13)

# %%
# merging all male csv files from jog_16
jog16_AgeGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_jog16.csv', 'sub_4_jog16.csv', 'sub_9_jog16.csv', 'sub_10_jog16.csv', 'sub_12_jog16.csv', 'sub_13_jog16.csv', 'sub_14_jog16.csv', 'sub_15_jog16.csv', 'sub_22_jog16.csv']), ignore_index=True)
print(jog16_AgeGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       2.135357       -1.138555      1.678900   0.353903
# 1               1       2.162745       -1.152928      1.739330   0.336766
# 2               2       2.175561       -1.166584      1.770651   0.323538
# 3               3       2.105621       -1.194708      1.696332   0.315997
# 4               4       2.021151       -1.202365      1.626949   0.324243
# ...           ...            ...             ...           ...        ...
# 11164        1463       2.625511       -1.444273      0.859824   0.062197
# 11165        1464       2.983922       -1.442248      1.179851   0.020106
# 11166        1465      -3.019766       -1.433483      1.426805  -0.016618
# 11167        1466      -2.837716       -1.423747      1.585341  -0.043803
# 11168        1467      -2.751986       -1.425407      1.669631  -0.054978
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
jog16_AgeGroup2_df = jog16_AgeGroup2_df.iloc[: , 1:]
jog16_AgeGroup2_df.shape
# Out:
# (11169, 12)

# %%
# Add Class Variable "Activity" in dataframe
jog16_AgeGroup2_df["Activity"] = 'Jogging' 
jog16_AgeGroup2_df.shape
# Out:
# (11169, 13)

# %%
# merging all AgeGroup1 csv files from dws_1
dws1_AgeGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_2_dws1.csv', 'sub_3_dws1.csv', 'sub_5_dws1.csv', 'sub_6_dws1.csv', 'sub_7_dws1.csv', 'sub_8_dws1.csv', 'sub_11_dws1.csv', 'sub_16_dws1.csv', 'sub_17_dws1.csv', 'sub_18_dws1.csv', 'sub_19_dws1.csv', 'sub_20_dws1.csv', 'sub_21_dws1.csv', 'sub_23_dws1.csv', 'sub_24_dws1.csv']), ignore_index=True)
print(dws1_AgeGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.469622       -1.105773     -0.183192   0.202940
# 1               1       0.515396       -1.156214     -0.173921   0.198531
# 2               2       0.557269       -1.211266     -0.162511   0.186069
# 3               3       0.601952       -1.255618     -0.113787   0.175522
# 4               4       0.674214       -1.284314      0.008391   0.176399
# ...           ...            ...             ...           ...        ...
# 33397        1642       1.900272       -1.384036      1.070332   0.175689
# 33398        1643       1.996873       -1.369482      1.160633   0.182080
# 33399        1644       2.074751       -1.350028      1.228313   0.191755
# 33400        1645       2.139869       -1.337114      1.289072   0.195067
# 33401        1646       2.272042       -1.327628      1.417406   0.183965
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws1_AgeGroup1_df = dws1_AgeGroup1_df.iloc[: , 1:]
dws1_AgeGroup1_df.shape
# Out:
# (33402, 12)

# %%
# Add Class Variable "Activity" in dataframe
dws1_AgeGroup1_df["Activity"] = 'Walking_DownStairs' 
dws1_AgeGroup1_df.shape
# Out:
# (33402, 13)

# %%
# merging all male csv files from dws_1
dws1_AgeGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_dws1.csv', 'sub_4_dws1.csv', 'sub_9_dws1.csv', 'sub_10_dws1.csv', 'sub_12_dws1.csv', 'sub_13_dws1.csv', 'sub_14_dws1.csv', 'sub_15_dws1.csv', 'sub_22_dws1.csv']), ignore_index=True)
print(dws1_AgeGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.528132       -0.733896      0.696372   0.741895
# 1               1       1.527992       -0.716987      0.677762   0.753099
# 2               2       1.527765       -0.706999      0.670951   0.759611
# 3               3       1.516768       -0.704678      0.675735   0.760709
# 4               4       1.493941       -0.703918      0.672994   0.760062
# ...           ...            ...             ...           ...        ...
# 16839        1819       0.654484       -1.046152     -2.750981   0.304922
# 16840        1820       0.665439       -0.992830     -2.730912   0.337297
# 16841        1821       0.680146       -0.961199     -2.717366   0.360069
# 16842        1822       0.709875       -0.950585     -2.699831   0.378791
# 16843        1823       0.744389       -0.954610     -2.671356   0.391555
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws1_AgeGroup2_df = dws1_AgeGroup2_df.iloc[: , 1:]
dws1_AgeGroup2_df.shape
# Out:
# (16844, 12)

# %%
# Add Class Variable "Activity" in dataframe
dws1_AgeGroup2_df["Activity"] = 'Walking_DownStairs' 
dws1_AgeGroup2_df.shape
# Out:
# (16844, 13)

# %%
# merging all AgeGroup1 csv files from dws_2
dws2_AgeGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_2_dws2.csv', 'sub_3_dws2.csv', 'sub_5_dws2.csv', 'sub_6_dws2.csv', 'sub_7_dws2.csv', 'sub_8_dws2.csv', 'sub_11_dws2.csv', 'sub_16_dws2.csv', 'sub_17_dws2.csv', 'sub_18_dws2.csv', 'sub_19_dws2.csv', 'sub_20_dws2.csv', 'sub_21_dws2.csv', 'sub_23_dws2.csv', 'sub_24_dws2.csv']), ignore_index=True)
print(dws2_AgeGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.116161       -1.042783      1.123054   0.452637
# 1               1       1.099274       -1.042618      1.098033   0.448963
# 2               2       1.120430       -1.041527      1.054091   0.454553
# 3               3       1.126466       -1.037457      1.008698   0.459040
# 4               4       1.127276       -1.034457      0.979404   0.461549
# ...           ...            ...             ...           ...        ...
# 39466        1456      -2.717883       -1.332958     -2.303607  -0.096867
# 39467        1457      -2.675661       -1.316127     -2.168156  -0.113179
# 39468        1458      -2.624580       -1.300916     -2.046566  -0.131785
# 39469        1459      -2.553919       -1.289668     -1.899243  -0.153820
# 39470        1460      -2.477694       -1.283688     -1.738934  -0.174494
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws2_AgeGroup1_df = dws2_AgeGroup1_df.iloc[: , 1:]
dws2_AgeGroup1_df.shape
# Out:
# (39471, 12)

# %%
# Add Class Variable "Activity" in dataframe
dws2_AgeGroup1_df["Activity"] = 'Walking_DownStairs' 
dws2_AgeGroup1_df.shape
# Out:
# (39471, 13)

# %%
# merging all male csv files from dws_2
dws2_AgeGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_dws2.csv', 'sub_4_dws2.csv', 'sub_9_dws2.csv', 'sub_10_dws2.csv', 'sub_12_dws2.csv', 'sub_13_dws2.csv', 'sub_14_dws2.csv', 'sub_15_dws2.csv', 'sub_22_dws2.csv']), ignore_index=True)
print(dws2_AgeGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.055270       -0.954541     -0.609278   0.031929
# 1               1       0.034557       -0.942493     -0.606960   0.020308
# 2               2       0.016687       -0.959855     -0.610954   0.009572
# 3               3       0.000695       -1.003050     -0.620385   0.000374
# 4               4      -0.017676       -1.060086     -0.634626  -0.008640
# ...           ...            ...             ...           ...        ...
# 19632        1915       0.821318       -1.002044      0.010088   0.394260
# 19633        1916       0.813559       -0.945642     -0.012615   0.425298
# 19634        1917       0.802957       -0.911150     -0.011541   0.440879
# 19635        1918       0.783794       -0.898710     -0.016435   0.439548
# 19636        1919       0.765903       -0.900199     -0.037666   0.430781
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws2_AgeGroup2_df = dws2_AgeGroup2_df.iloc[: , 1:]
dws2_AgeGroup2_df.shape
# Out:
# (19637, 12)

# %%
# Add Class Variable "Activity" in dataframe
dws2_AgeGroup2_df["Activity"] = 'Walking_DownStairs' 
dws2_AgeGroup2_df.shape
# Out:
# (19637, 13)

# %%
# merging all AgeGroup1 csv files from dws_11
dws11_AgeGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_2_dws11.csv', 'sub_3_dws11.csv', 'sub_5_dws11.csv', 'sub_6_dws11.csv', 'sub_7_dws11.csv', 'sub_8_dws11.csv', 'sub_11_dws11.csv', 'sub_16_dws11.csv', 'sub_17_dws11.csv', 'sub_18_dws11.csv', 'sub_19_dws11.csv', 'sub_20_dws11.csv', 'sub_21_dws11.csv', 'sub_23_dws11.csv', 'sub_24_dws11.csv']), ignore_index=True)
print(dws11_AgeGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.443573       -1.103011      0.299928   0.447265
# 1               1       1.449266       -1.114364      0.307347   0.437496
# 2               2       1.426510       -1.116849      0.287504   0.433958
# 3               3       1.382342       -1.112301      0.231110   0.434762
# 4               4       1.359921       -1.107740      0.168207   0.436788
# ...           ...            ...             ...           ...        ...
# 15062         434      -2.630665       -0.942106     -2.692480  -0.287566
# 15063         435      -2.622877       -0.941469     -2.686673  -0.291808
# 15064         436      -2.632187       -0.962013     -2.683334  -0.278877
# 15065         437      -2.642530       -1.004807     -2.675556  -0.256651
# 15066         438      -2.644099       -1.077019     -2.663269  -0.226183
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws11_AgeGroup1_df = dws11_AgeGroup1_df.iloc[: , 1:]
dws11_AgeGroup1_df.shape
# Out:
# (15067, 12)

# %%
# Add Class Variable "Activity" in dataframe
dws11_AgeGroup1_df["Activity"] = 'Walking_DownStairs' 
dws11_AgeGroup1_df.shape
# Out:
# (15067, 13)

# %%
# merging all male csv files from dws_11
dws11_AgeGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_dws11.csv', 'sub_4_dws11.csv', 'sub_9_dws11.csv', 'sub_10_dws11.csv', 'sub_12_dws11.csv', 'sub_13_dws11.csv', 'sub_14_dws11.csv', 'sub_15_dws11.csv', 'sub_22_dws11.csv']), ignore_index=True)
print(dws11_AgeGroup2_df)
# Out:
#       Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0              0       0.086504       -1.172129      1.181660   0.033538
# 1              1       0.059454       -1.146609      1.248254   0.024456
# 2              2       0.029339       -1.130040      1.295114   0.012515
# 3              3      -0.004340       -1.119799      1.327633  -0.001892
# 4              4      -0.041066       -1.118417      1.351262  -0.017945
# ...          ...            ...             ...           ...        ...
# 7430         691       1.198224       -1.289482     -2.144893   0.258573
# 7431         692       1.172314       -1.307875     -2.170818   0.239539
# 7432         693       1.113915       -1.319807     -2.233084   0.222888
# 7433         694       1.069544       -1.320696     -2.305056   0.217053
# 7434         695       0.996454       -1.307672     -2.417663   0.218365
#
#       gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws11_AgeGroup2_df = dws11_AgeGroup2_df.iloc[: , 1:]
dws11_AgeGroup2_df.shape
# Out:
# (7435, 12)

# %%
# Add Class Variable "Activity" in dataframe
dws11_AgeGroup2_df["Activity"] = 'Walking_DownStairs' 
dws11_AgeGroup2_df.shape
# Out:
# (7435, 13)

# %%
# merging all AgeGroup1 csv files from ups_3 
ups3_AgeGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_2_ups3.csv', 'sub_3_ups3.csv', 'sub_5_ups3.csv', 'sub_6_ups3.csv', 'sub_7_ups3.csv', 'sub_8_ups3.csv', 'sub_11_ups3.csv', 'sub_16_ups3.csv', 'sub_17_ups3.csv', 'sub_18_ups3.csv', 'sub_19_ups3.csv', 'sub_20_ups3.csv', 'sub_21_ups3.csv', 'sub_23_ups3.csv', 'sub_24_ups3.csv']), ignore_index=True)
print(ups3_AgeGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -2.339597       -1.322160     -2.566389  -0.176869
# 1               1      -2.132033       -1.352349     -2.347691  -0.183466
# 2               2      -1.754546       -1.361932     -1.946346  -0.203855
# 3               3      -1.265691       -1.321572     -1.428545  -0.235259
# 4               4      -0.934066       -1.232729     -1.114953  -0.266672
# ...           ...            ...             ...           ...        ...
# 38961        1392       1.225887       -1.380504     -0.586724   0.178006
# 38962        1393       1.702697       -1.456976     -0.134149   0.112589
# 38963        1394       2.598022       -1.491832      0.750552   0.040798
# 38964        1395      -2.791966       -1.460973      1.655483  -0.037544
# 38965        1396      -2.489767       -1.380595      1.980176  -0.114689
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups3_AgeGroup1_df = ups3_AgeGroup1_df.iloc[: , 1:]
ups3_AgeGroup1_df.shape
# Out:
# (38966, 12)

# %%
# Add Class Variable "Activity" in dataframe
ups3_AgeGroup1_df["Activity"] = 'Walking_UpStairs' 
ups3_AgeGroup1_df.shape
# Out:
# (38966, 13)

# %%
# merging all male csv files from ups_3
ups3_AgeGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_ups3.csv', 'sub_4_ups3.csv', 'sub_9_ups3.csv', 'sub_10_ups3.csv', 'sub_12_ups3.csv', 'sub_13_ups3.csv', 'sub_14_ups3.csv', 'sub_15_ups3.csv', 'sub_22_ups3.csv']), ignore_index=True)
print(ups3_AgeGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -2.643769       -1.348560      1.938935  -0.105250
# 1               1      -2.611424       -1.325624      1.946019  -0.122740
# 2               2      -2.544143       -1.316334      2.003067  -0.141604
# 3               3      -2.506960       -1.308531      2.043615  -0.153716
# 4               4      -2.528618       -1.296898      2.026038  -0.155612
# ...           ...            ...             ...           ...        ...
# 19233        2392       0.710971       -1.053417      3.083730   0.322751
# 19234        2393       0.694973       -0.997367      3.094061   0.347397
# 19235        2394       0.681214       -0.941093      3.101978   0.370846
# 19236        2395       0.663800       -0.883853      3.108506   0.390718
# 19237        2396       0.641690       -0.828455      3.115239   0.404623
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups3_AgeGroup2_df = ups3_AgeGroup2_df.iloc[: , 1:]
ups3_AgeGroup2_df.shape
# Out:
# (19238, 12)

# %%
# Add Class Variable "Activity" in dataframe
ups3_AgeGroup2_df["Activity"] = 'Walking_UpStairs' 
ups3_AgeGroup2_df.shape
# Out:
# (19238, 13)

# %%
# merging all AgeGroup1 csv files from ups_4
ups4_AgeGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_2_ups4.csv', 'sub_3_ups4.csv', 'sub_5_ups4.csv', 'sub_6_ups4.csv', 'sub_7_ups4.csv', 'sub_8_ups4.csv', 'sub_11_ups4.csv', 'sub_16_ups4.csv', 'sub_17_ups4.csv', 'sub_18_ups4.csv', 'sub_19_ups4.csv', 'sub_20_ups4.csv', 'sub_21_ups4.csv', 'sub_23_ups4.csv', 'sub_24_ups4.csv']), ignore_index=True)
print(ups4_AgeGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.083452       -0.589521     -0.673704   0.069285
# 1               1       0.117583       -0.612342     -0.691317   0.095997
# 2               2       0.144807       -0.635371     -0.702397   0.116141
# 3               3       0.171258       -0.660547     -0.704045   0.134575
# 4               4       0.205200       -0.693131     -0.701621   0.156745
# ...           ...            ...             ...           ...        ...
# 46583        1507      -2.208286       -0.734780     -0.350465  -0.596249
# 46584        1508      -2.146088       -0.788391     -0.322954  -0.591508
# 46585        1509      -2.094428       -0.834623     -0.287080  -0.581488
# 46586        1510      -2.071408       -0.876276     -0.254023  -0.561480
# 46587        1511      -2.071189       -0.922735     -0.236846  -0.529632
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups4_AgeGroup1_df = ups4_AgeGroup1_df.iloc[: , 1:]
ups4_AgeGroup1_df.shape
# Out:
# (46588, 12)

# %%
# Add Class Variable "Activity" in dataframe
ups4_AgeGroup1_df["Activity"] = 'Walking_UpStairs' 
ups4_AgeGroup1_df.shape
# Out:
# (46588, 13)

# %%
# merging all male csv files from ups_4
ups4_AgeGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_ups4.csv', 'sub_4_ups4.csv', 'sub_9_ups4.csv', 'sub_10_ups4.csv', 'sub_12_ups4.csv', 'sub_13_ups4.csv', 'sub_14_ups4.csv', 'sub_15_ups4.csv', 'sub_22_ups4.csv']), ignore_index=True)
print(ups4_AgeGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.348443       -0.817831      0.539156   0.233475
# 1               1       0.391896       -0.851445      0.553602   0.251660
# 2               2       0.448344       -0.888969      0.574567   0.273181
# 3               3       0.502052       -0.913294      0.588488   0.294097
# 4               4       0.556119       -0.928739      0.603094   0.316126
# ...           ...            ...             ...           ...        ...
# 24479        2705       0.962558       -1.348018     -0.212840   0.181314
# 24480        2706       0.904613       -1.280573     -0.297308   0.224978
# 24481        2707       0.895363       -1.204473     -0.330658   0.279540
# 24482        2708       0.916626       -1.133916     -0.317438   0.335764
# 24483        2709       0.943784       -1.071933     -0.282755   0.387423
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups4_AgeGroup2_df = ups4_AgeGroup2_df.iloc[: , 1:]
ups4_AgeGroup2_df.shape
# Out:
# (24484, 12)

# %%
# Add Class Variable "Activity" in dataframe
ups4_AgeGroup2_df["Activity"] = 'Walking_UpStairs' 
ups4_AgeGroup2_df.shape
# Out:
# (24484, 13)

# %%
# merging all AgeGroup1 csv files from ups_12
ups12_AgeGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_2_ups12.csv', 'sub_3_ups12.csv', 'sub_5_ups12.csv', 'sub_6_ups12.csv', 'sub_7_ups12.csv', 'sub_8_ups12.csv', 'sub_11_ups12.csv', 'sub_16_ups12.csv', 'sub_17_ups12.csv', 'sub_18_ups12.csv', 'sub_19_ups12.csv', 'sub_20_ups12.csv', 'sub_21_ups12.csv', 'sub_23_ups12.csv', 'sub_24_ups12.csv']), ignore_index=True)
print(ups12_AgeGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.549556       -1.246213     -0.500761   0.166568
# 1               1       0.615927       -1.285635     -0.417540   0.162513
# 2               2       0.741631       -1.316992     -0.264949   0.169602
# 3               3       0.964566       -1.333428     -0.035615   0.193234
# 4               4       1.209474       -1.335457      0.194874   0.218106
# ...           ...            ...             ...           ...        ...
# 18406         738      -0.476418       -1.215394     -1.091883  -0.159578
# 18407         739      -0.426007       -1.230329     -1.132637  -0.137992
# 18408         740      -0.351505       -1.215819     -1.095573  -0.119672
# 18409         741      -0.329081       -1.205736     -1.106650  -0.115375
# 18410         742      -0.363036       -1.209536     -1.155255  -0.125516
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups12_AgeGroup1_df = ups12_AgeGroup1_df.iloc[: , 1:]
ups12_AgeGroup1_df.shape
# Out:
# (18411, 12)

# %%
# Add Class Variable "Activity" in dataframe
ups12_AgeGroup1_df["Activity"] = 'Walking_UpStairs' 
ups12_AgeGroup1_df.shape
# Out:
# (18411, 13)

# %%
# merging all male csv files from ups_12
ups12_AgeGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_1_ups12.csv', 'sub_4_ups12.csv', 'sub_9_ups12.csv', 'sub_10_ups12.csv', 'sub_12_ups12.csv', 'sub_13_ups12.csv', 'sub_14_ups12.csv', 'sub_15_ups12.csv', 'sub_22_ups12.csv']), ignore_index=True)
print(ups12_AgeGroup2_df)
# Out:
#       Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0              0       0.838472       -0.901646      0.189667   0.461284
# 1              1       0.901238       -0.900320      0.177763   0.487205
# 2              2       0.993089       -0.914963      0.185652   0.510856
# 3              3       1.029530       -0.921919      0.171090   0.517913
# 4              4       1.052038       -0.927877      0.156188   0.520657
# ...          ...            ...             ...           ...        ...
# 9593        1003      -0.198957       -1.453118      2.183427  -0.023201
# 9594        1004       0.203950       -1.399843      2.576332   0.034453
# 9595        1005       0.420937       -1.351860      2.813387   0.088743
# 9596        1006       0.552714       -1.308184      2.972340   0.136288
# 9597        1007       0.660519       -1.264018      3.092469   0.185274
#
#       gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups12_AgeGroup2_df = ups12_AgeGroup2_df.iloc[: , 1:]
ups12_AgeGroup2_df.shape
# Out:
# (9598, 12)

# %%
# Add Class Variable "Activity" in dataframe
ups12_AgeGroup2_df["Activity"] = 'Walking_UpStairs' 
ups12_AgeGroup2_df.shape
# Out:
# (9598, 13)

# %% [markdown]
# **Combining all activities of Age_Group frames in a single frame**

# %%
all_activities_AgeGroup1_frame = [wlk7_AgeGroup1_df, wlk8_AgeGroup1_df, wlk15_AgeGroup1_df, std6_AgeGroup1_df, std14_AgeGroup1_df, sit5_AgeGroup1_df, sit13_AgeGroup1_df, jog9_AgeGroup1_df, jog16_AgeGroup1_df, dws1_AgeGroup1_df, dws2_AgeGroup1_df, dws11_AgeGroup1_df, ups3_AgeGroup1_df, ups4_AgeGroup1_df, ups12_AgeGroup1_df]

all_activities_AgeGroup1_df = pd.concat(all_activities_AgeGroup1_frame) 
all_activities_AgeGroup1_df.shape
# Out:
# (901157, 13)

# %%
# Shuffle/Mix the dataframe rows 
all_activities_AgeGroup1_df.sample(frac=1) 
all_activities_AgeGroup1_df.shape
# Out:
# (901157, 13)

# %%
all_activities_AgeGroup2_frames = [wlk7_AgeGroup2_df, wlk8_AgeGroup2_df, wlk15_AgeGroup2_df, std6_AgeGroup2_df, std14_AgeGroup2_df, sit5_AgeGroup2_df, sit13_AgeGroup2_df, jog9_AgeGroup2_df, jog16_AgeGroup2_df, dws1_AgeGroup2_df, dws2_AgeGroup2_df, dws11_AgeGroup2_df, ups3_AgeGroup2_df, ups4_AgeGroup2_df, ups12_AgeGroup2_df]

all_activities_AgeGroup2_df = pd.concat(all_activities_AgeGroup2_frames)
all_activities_AgeGroup2_df.shape
# Out:
# (511708, 13)

# %%
# Shuffle the dataframe rows 
all_activities_AgeGroup2_df.sample(frac=1) 
all_activities_AgeGroup2_df.shape
# Out:
# (511708, 13)

# %%
all_activities_AgeGroup2_df.isna().sum().sum()
# Out:
# 0

# %%
# print(all_activity_AgeGroup1_df) 
# print(all_activity_AgeGroup2_df)

# %% [markdown]
# **Classification**

# %%
# importing libraries 
from sklearn import metrics
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier 
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier # Xtreme Gradient Boosting 
from lightgbm import LGBMClassifier 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# AgeGroupWise classification using five classifiers

# %%
# RF over AgeGroup1 data

# %%
# Preparing Input and Output Splits 
X = all_activities_AgeGroup1_df.iloc[:, :-1].values
y = all_activities_AgeGroup1_df.iloc[:, -1].values

# %%
X.shape, y.shape
# Out:
# ((901157, 12), (901157,))

# %%
# Train Test Splits with a ratio of 70:30 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((630809, 12), (270348, 12), (630809,), (270348,))

# %%
# define the model applying Random Forest 
rf = RandomForestClassifier() 
gnb = GaussianNB() 
lr = LogisticRegression() 
ab = AdaBoostClassifier()
dt = DecisionTreeClassifier()
bagging = BaggingClassifier()
xgb = XGBClassifier() 
lgbm = LGBMClassifier()

# %%
#Train the model using the training sets
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#Predict the response for test dataset 
y_pred = rf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9426405965644281

# %%
#Train the model using the training sets
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#Predict the response for test dataset 
y_pred = gnb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6836965688667939

# %%
#Train the model using the training sets
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Predict the response for test dataset 
y_pred = lr.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.531977303327563

# %%
#Train the model using the training sets
ab.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
#Predict the response for test dataset 
y_pred = ab.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5918815748590706

# %%
#Train the model using the training sets
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Predict the response for test dataset 
y_pred = dt.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8712141388136772

# %%
#Train the model using the training sets
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
#Predict the response for test dataset 
y_pred = xgb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.791875656561173

# %%
#Train the model using the training sets
lgbm.fit(X_train, y_train)
# Out:
# LGBMClassifier()

# %%
#Predict the response for test dataset 
y_pred = lgbm.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8617004749434063

# %%
#Train the model using the training sets
bagging.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
#Predict the response for test dataset 
y_pred = bagging.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9118580496249279

# %%
# RF over AgeGroup2 data

# %%
# Preparing Input and Output Splits 
X_AgeGroup2 = all_activities_AgeGroup2_df.iloc[:, :-1].values
y_AgeGroup2 = all_activities_AgeGroup2_df.iloc[:, -1].values

# %%
# Train Test Splits with a ratio of 70:30 
X_train, X_test, y_train, y_test = train_test_split(X_AgeGroup2, y_AgeGroup2, test_size = 0.30)

# %%
#Train the model using the training sets
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#Predict the response for test dataset
y_pred = rf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9464931308749096

# %%
#Train the model using the training sets
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#Predict the response for test dataset
y_pred = gnb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7354230586334708

# %%
#Train the model using the training sets
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Predict the response for test dataset
y_pred = lr.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5853966765029672

# %%
#Train the model using the training sets
ab.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
#Predict the response for test dataset
y_pred = ab.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6809781582015856

# %%
#Train the model using the training sets
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Predict the response for test dataset
y_pred = dt.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8883091334284393

# %%
#Train the model using the training sets
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
#Predict the response for test dataset
y_pred = xgb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8142828294672112

# %%
#Train the model using the training sets
lgbm.fit(X_train, y_train)
# Out:
# LGBMClassifier()

# %%
#Predict the response for test dataset
y_pred = lgbm.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8811957293519116

# %%
#Train the model using the training sets
bagging.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
#Predict the response for test dataset
y_pred = bagging.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9256545048302098

# %%
# Training on AgeGroup1 data and testing on AgeGroup2

# %%
# Preparing Input and Output Splits 
X_all_AgeGroup1_train = all_activities_AgeGroup1_df.iloc[:, :-1].values
y_all_AgeGroup1_train = all_activities_AgeGroup1_df.iloc[:, -1].values

# %%
# Preparing Input and Output Splits 
X_all_AgeGroup2_test = all_activities_AgeGroup2_df.iloc[:, :-1].values
y_all_AgeGroup2_test = all_activities_AgeGroup2_df.iloc[:, -1].values

# %%
#Train the model using the training sets
rf.fit(X_all_AgeGroup1_train, y_all_AgeGroup1_train)
# Out:
# RandomForestClassifier()

# %%
#Predict the response for test dataset 
y_pred = rf.predict(X_all_AgeGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_AgeGroup2_test, y_pred))
# Out:
# Accuracy: 0.6961880603781845

# %%
#Train the model using the training sets
gnb.fit(X_all_AgeGroup1_train, y_all_AgeGroup1_train)
# Out:
# GaussianNB()

# %%
#Predict the response for test dataset 
y_pred = gnb.predict(X_all_AgeGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_AgeGroup2_test, y_pred))
# Out:
# Accuracy: 0.6879411695732722

# %%
#Train the model using the training sets
lr.fit(X_all_AgeGroup1_train, y_all_AgeGroup1_train)
# Out:
# LogisticRegression()

# %%
#Predict the response for test dataset 
y_pred = lr.predict(X_all_AgeGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_AgeGroup2_test, y_pred))
# Out:
# Accuracy: 0.5360166344868558

# %%
#Train the model using the training sets
ab.fit(X_all_AgeGroup1_train, y_all_AgeGroup1_train)
# Out:
# AdaBoostClassifier()

# %%
#Predict the response for test dataset 
y_pred = ab.predict(X_all_AgeGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_AgeGroup2_test, y_pred))
# Out:
# Accuracy: 0.6345259405754845

# %%
#Train the model using the training sets
dt.fit(X_all_AgeGroup1_train, y_all_AgeGroup1_train)
# Out:
# DecisionTreeClassifier()

# %%
#Predict the response for test dataset 
y_pred = dt.predict(X_all_AgeGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_AgeGroup2_test, y_pred))
# Out:
# Accuracy: 0.6321593565080085

# %%
#Train the model using the training sets
xgb.fit(X_all_AgeGroup1_train, y_all_AgeGroup1_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
#Predict the response for test dataset 
y_pred = xgb.predict(X_all_AgeGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_AgeGroup2_test, y_pred))
# Out:
# Accuracy: 0.7381944390160013

# %%
#Train the model using the training sets
lgbm.fit(X_all_AgeGroup1_train, y_all_AgeGroup1_train)
# Out:
# LGBMClassifier()

# %%
#Predict the response for test dataset 
y_pred = lgbm.predict(X_all_AgeGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_AgeGroup2_test, y_pred))
# Out:
# Accuracy: 0.726001938605611

# %%
#Train the model using the training sets
bagging.fit(X_all_AgeGroup1_train, y_all_AgeGroup1_train)
# Out:
# BaggingClassifier()

# %%
#Predict the response for test dataset 
y_pred = bagging.predict(X_all_AgeGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_AgeGroup2_test, y_pred))
# Out:
# Accuracy: 0.6724030110922635

# %%
# Training on AgeGroup2 data and testing on AgeGroup1

# %%
# Preparing Input and Output Splits 
X_all_AgeGroup1_test = all_activities_AgeGroup1_df.iloc[:, :-1].values 
y_all_AgeGroup1_test = all_activities_AgeGroup1_df.iloc[:, -1].values

# %%
# Preparing Input and Output Splits 
X_all_AgeGroup2_train = all_activities_AgeGroup2_df.iloc[:, :-1].values
y_all_AgeGroup2_train = all_activities_AgeGroup2_df.iloc[:, -1].values

# %%
#Train the model using the training sets
rf.fit(X_all_AgeGroup2_train, y_all_AgeGroup2_train)
# Out:
# RandomForestClassifier()

# %%
#Predict the response for test dataset 
y_pred = rf.predict(X_all_AgeGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_AgeGroup1_test, y_pred))
# Out:
# Accuracy: 0.6862622162397896

# %%
#Train the model using the training sets
gnb.fit(X_all_AgeGroup2_train, y_all_AgeGroup2_train)
# Out:
# GaussianNB()

# %%
#Predict the response for test dataset 
y_pred = gnb.predict(X_all_AgeGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_AgeGroup1_test, y_pred))
# Out:
# Accuracy: 0.6912990744121169

# %%
#Train the model using the training sets
lr.fit(X_all_AgeGroup2_train, y_all_AgeGroup2_train)
# Out:
# LogisticRegression()

# %%
#Predict the response for test dataset 
y_pred = lr.predict(X_all_AgeGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_AgeGroup1_test, y_pred))
# Out:
# Accuracy: 0.5024285446376159

# %%
#Train the model using the training sets
ab.fit(X_all_AgeGroup2_train, y_all_AgeGroup2_train)
# Out:
# AdaBoostClassifier()

# %%
#Predict the response for test dataset 
y_pred = ab.predict(X_all_AgeGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_AgeGroup1_test, y_pred))
# Out:
# Accuracy: 0.5522755746224021

# %%
#Train the model using the training sets
dt.fit(X_all_AgeGroup2_train, y_all_AgeGroup2_train)
# Out:
# DecisionTreeClassifier()

# %%
#Predict the response for test dataset 
y_pred = dt.predict(X_all_AgeGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_AgeGroup1_test, y_pred))
# Out:
# Accuracy: 0.5711324441800929

# %%
#Train the model using the training sets
xgb.fit(X_all_AgeGroup2_train, y_all_AgeGroup2_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
#Predict the response for test dataset 
y_pred = xgb.predict(X_all_AgeGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_AgeGroup1_test, y_pred))
# Out:
# Accuracy: 0.7086512117200443

# %%
#Train the model using the training sets
lgbm.fit(X_all_AgeGroup2_train, y_all_AgeGroup2_train)
# Out:
# LGBMClassifier()

# %%
#Predict the response for test dataset 
y_pred = lgbm.predict(X_all_AgeGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_AgeGroup1_test, y_pred))
# Out:
# Accuracy: 0.6936227538597602

# %%
#Train the model using the training sets
bagging.fit(X_all_AgeGroup2_train, y_all_AgeGroup2_train)
# Out:
# BaggingClassifier()

# %%
#Predict the response for test dataset 
y_pred = bagging.predict(X_all_AgeGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_AgeGroup1_test, y_pred))
# Out:
# Accuracy: 0.614537755352286

# %%
# Combining data of all activities and both groups

# %%
all_activities_Both_AgeGroups_frame = [all_activities_AgeGroup1_df, all_activities_AgeGroup2_df]

all_activities_Both_AgeGroups_df = pd.concat(all_activities_Both_AgeGroups_frame)
all_activities_Both_AgeGroups_df.shape
# Out:
# (1412865, 13)

# %%
X = all_activities_Both_AgeGroups_df.iloc[:, :-1].values
y = all_activities_Both_AgeGroups_df.iloc[:, -1].values

# %%
X.shape, y.shape
# Out:
# ((1412865, 12), (1412865,))

# %%
# Train Test Splits with a ratio of 70:30 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %%
#Train the model using the training sets
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#Predict the response for test dataset 
y_pred = rf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9310527060821969

# %%
#Train the model using the training sets
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#Predict the response for test dataset 
y_pred = gnb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7261642995328647

# %%
#Train the model using the training sets
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Predict the response for test dataset 
y_pred = lr.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5412518284339168

# %%
#Train the model using the training sets
ab.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
#Predict the response for test dataset 
y_pred = ab.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6798140895578729

# %%
#Train the model using the training sets
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Predict the response for test dataset 
y_pred = dt.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8562284716651725

# %%
#Train the model using the training sets
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
#Predict the response for test dataset 
y_pred = xgb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7816519605530128

# %%
#Train the model using the training sets
lgbm.fit(X_train, y_train)
# Out:
# LGBMClassifier()

# %%
#Predict the response for test dataset 
y_pred = lgbm.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8422191289576747

# %%
#Train the model using the training sets
bagging.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
#Predict the response for test dataset 
y_pred = bagging.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9019534752040769
