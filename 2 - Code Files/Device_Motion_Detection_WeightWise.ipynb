# %%
import pandas as pd
import glob

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-1ab5480c-1997-463d-8f42-2fba5697a702" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1ab5480c-1997-463d-8f42-2fba5697a702">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sub_1.csv to sub_1.csv
# Saving sub_1_dws1.csv to sub_1_dws1.csv
# Saving sub_1_dws2.csv to sub_1_dws2.csv
# Saving sub_1_dws11.csv to sub_1_dws11.csv
# Saving sub_1_jog9.csv to sub_1_jog9.csv
# Saving sub_1_jog16.csv to sub_1_jog16.csv
# Saving sub_1_sit5.csv to sub_1_sit5.csv
# Saving sub_1_sit13.csv to sub_1_sit13.csv
# Saving sub_1_std6.csv to sub_1_std6.csv
# Saving sub_1_std14.csv to sub_1_std14.csv
# Saving sub_1_ups3.csv to sub_1_ups3.csv
# Saving sub_1_ups4.csv to sub_1_ups4.csv
# Saving sub_1_ups12.csv to sub_1_ups12.csv
# ...

# %%
# merging all WeightGroup1 csv files from wlk_7
wlk7_WeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_1.csv', 'sub_2.csv', 'sub_3.csv', 'sub_5.csv', 'sub_7.csv', 'sub_8.csv', 'sub_10.csv', 'sub_11.csv', 'sub_12.csv', 'sub_13.csv', 'sub_14.csv', 'sub_15.csv', 'sub_18.csv', 'sub_21.csv', 'sub_23.csv', 'sub_24.csv']), ignore_index=True)
print(wlk7_WeightGroup1_df)
# Out:
#         Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0                0      -1.711140       -1.429168     -2.591433  -0.139767
# 1                1      -1.787917       -1.414171     -2.630956  -0.152324
# 2                2      -1.897323       -1.399331     -2.706668  -0.161610
# 3                3      -2.018375       -1.383279     -2.813421  -0.168058
# 4                4      -2.124395       -1.364054     -2.913092  -0.174613
# ...            ...            ...             ...           ...        ...
# 103469        5016       1.456354        0.025356      2.896466   0.993139
# 103470        5017       1.435872       -0.007495      2.934749   0.990884
# 103471        5018       1.438846       -0.054606      2.985588   0.989830
# 103472        5019       1.454454       -0.112258      3.026277   0.986988
# 103473        5020       1.437505       -0.167232      3.047170   0.977303
#
# ...

# %%
# Drop first column of dataframe
wlk7_WeightGroup1_df = wlk7_WeightGroup1_df.iloc[: , 1:]
wlk7_WeightGroup1_df.shape
# Out:
# (103474, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk7_WeightGroup1_df["Activity"] = 'Walking' 
wlk7_WeightGroup1_df.shape
# Out:
# (103474, 13)

# %%
# merging all WeightGroup2 csv files from wlk_7 
wlk7_WeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_4.csv', 'sub_6.csv', 'sub_9.csv', 'sub_16.csv', 'sub_17.csv', 'sub_19.csv', 'sub_20.csv', 'sub_22.csv']), ignore_index=True)
print(wlk7_WeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -0.569732       -1.344266     -1.316934  -0.121138
# 1               1      -0.721397       -1.359857     -1.513063  -0.138265
# 2               2      -0.783814       -1.362296     -1.637286  -0.146117
# 3               3      -0.843923       -1.361021     -1.717798  -0.155590
# 4               4      -0.963102       -1.372325     -1.850983  -0.161848
# ...           ...            ...             ...           ...        ...
# 55166        6437       0.820939       -1.010720     -0.679626   0.388757
# 55167        6438       0.812806       -0.966541     -0.656513   0.412596
# 55168        6439       0.803715       -0.939513     -0.626011   0.424890
# 55169        6440       0.783811       -0.914628     -0.599212   0.430707
# 55170        6441       0.758766       -0.895560     -0.577389   0.430069
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
wlk7_WeightGroup2_df = wlk7_WeightGroup2_df.iloc[: , 1:]
wlk7_WeightGroup2_df.shape
# Out:
# (55171, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk7_WeightGroup2_df["Activity"] = 'Walking' 
wlk7_WeightGroup2_df.shape
# Out:
# (55171, 13)

# %%
# merging all WeightGroup1 csv files from wlk_8
wlk8_WeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_1_w8.csv', 'sub_2_w8.csv', 'sub_3_w8.csv', 'sub_5_w8.csv', 'sub_7_w8.csv', 'sub_8_w8.csv', 'sub_10_w8.csv', 'sub_11_w8.csv', 'sub_12_w8.csv', 'sub_13_w8.csv', 'sub_14_w8.csv', 'sub_15_w8.csv', 'sub_18_w8.csv', 'sub_21_w8.csv', 'sub_23_w8.csv', 'sub_24_w8.csv']), ignore_index=True)
print(wlk8_WeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       2.255404       -1.421448      1.482931   0.115265
# 1               1       1.960381       -1.423633      1.195886   0.135644
# 2               2       1.648809       -1.412348      0.888191   0.157306
# 3               3       1.342174       -1.388827      0.616273   0.176258
# 4               4       1.121672       -1.355100      0.449400   0.192801
# ...           ...            ...             ...           ...        ...
# 79732        4071       0.732151       -1.023012     -2.798738   0.348138
# 79733        4072       0.719940       -0.958009     -2.811475   0.379219
# 79734        4073       0.738723       -0.946121     -2.745565   0.393794
# 79735        4074       0.722347       -0.976487     -2.779944   0.370201
# 79736        4075       0.700401       -0.988938     -2.833834   0.354216
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
wlk8_WeightGroup1_df = wlk8_WeightGroup1_df.iloc[: , 1:]
wlk8_WeightGroup1_df.shape
# Out:
# (79737, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk8_WeightGroup1_df["Activity"] = 'Walking' 
wlk8_WeightGroup1_df.shape
# Out:
# (79737, 13)

# %%
# merging all WeightGroup2 csv files from wlk_8 
wlk8_WeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_4_w8.csv', 'sub_6_w8.csv', 'sub_9_w8.csv', 'sub_16_w8.csv', 'sub_17_w8.csv', 'sub_19_w8.csv', 'sub_20_w8.csv', 'sub_22_w8.csv']), ignore_index=True)
print(wlk8_WeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -2.587829       -1.104663      1.308206  -0.236349
# 1               1      -2.603948       -1.080927      1.302430  -0.240950
# 2               2      -2.593966       -1.071469      1.305320  -0.249306
# 3               3      -2.586256       -1.065128      1.304012  -0.255381
# 4               4      -2.577064       -1.064164      1.309316  -0.259604
# ...           ...            ...             ...           ...        ...
# 40629        4943       0.941090       -1.092168      0.900210   0.372226
# 40630        4944       0.929729       -1.126047      0.878770   0.344811
# 40631        4945       0.927453       -1.159592      0.877930   0.319807
# 40632        4946       0.961754       -1.195810      0.910480   0.300404
# 40633        4947       1.041013       -1.233225      0.977956   0.285793
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
wlk8_WeightGroup2_df = wlk8_WeightGroup2_df.iloc[: , 1:]
wlk8_WeightGroup2_df.shape
# Out:
# (40634, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk8_WeightGroup2_df["Activity"] = 'Walking' 
wlk8_WeightGroup2_df.shape
# Out:
# (40634, 13)

# %%
# merging all WeightGroup1 csv files from wlk_15
wlk15_WeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_1_wlk15.csv', 'sub_2_wlk15.csv', 'sub_3_wlk15.csv', 'sub_5_wlk15.csv', 'sub_7_wlk15.csv', 'sub_8_wlk15.csv', 'sub_10_wlk15.csv', 'sub_11_wlk15.csv', 'sub_12_wlk15.csv', 'sub_13_wlk15.csv', 'sub_14_wlk15.csv', 'sub_15_wlk15.csv', 'sub_18_wlk15.csv', 'sub_21_wlk15.csv', 'sub_23_wlk15.csv', 'sub_24_wlk15.csv']), ignore_index=True)
print(wlk15_WeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -0.642341       -1.408409     -1.725791  -0.096855
# 1               1      -1.063803       -1.440007     -2.200242  -0.114011
# 2               2      -1.258381       -1.432875     -2.424099  -0.130829
# 3               3      -1.391648       -1.420133     -2.584396  -0.147692
# 4               4      -1.602210       -1.412241     -2.812153  -0.157814
# ...           ...            ...             ...           ...        ...
# 43285        2055      -1.287175       -1.180782      1.184133  -0.365012
# 43286        2056      -1.217304       -1.160821      1.208497  -0.373942
# 43287        2057      -1.083201       -1.167077      1.269294  -0.347061
# 43288        2058      -0.966096       -1.193223      1.348783  -0.303291
# 43289        2059      -0.989568       -1.205294      1.358403  -0.298726
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
wlk15_WeightGroup1_df = wlk15_WeightGroup1_df.iloc[: , 1:]
wlk15_WeightGroup1_df.shape
# Out:
# (43290, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk15_WeightGroup1_df["Activity"] = 'Walking' 
wlk15_WeightGroup1_df.shape
# Out:
# (43290, 13)

# %%
# merging all WeightGroup2 csv files from wlk_15 
wlk15_WeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_4_wlk15.csv', 'sub_6_wlk15.csv', 'sub_9_wlk15.csv', 'sub_16_wlk15.csv', 'sub_17_wlk15.csv', 'sub_19_wlk15.csv', 'sub_20_wlk15.csv', 'sub_22_wlk15.csv']), ignore_index=True)
print(wlk15_WeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -0.736002       -0.896397     -1.917891  -0.419196
# 1               1      -0.783130       -0.906767     -1.940364  -0.434795
# 2               2      -0.835255       -0.921664     -1.971187  -0.448212
# 3               3      -0.860242       -0.937620     -1.974393  -0.448513
# 4               4      -0.867391       -0.942021     -1.947695  -0.448550
# ...           ...            ...             ...           ...        ...
# 21977        2368       0.652484       -0.807196      0.146552   0.419865
# 21978        2369       0.622831       -0.843409      0.138808   0.387870
# 21979        2370       0.617302       -0.846571      0.128739   0.383509
# 21980        2371       0.645521       -0.830476      0.144746   0.405800
# 21981        2372       0.660655       -0.824494      0.171551   0.416610
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
wlk15_WeightGroup2_df = wlk15_WeightGroup2_df.iloc[: , 1:]
wlk15_WeightGroup2_df.shape
# Out:
# (21982, 12)

# %%
# Add Class Variable "Activity" in dataframe
wlk15_WeightGroup2_df["Activity"] = 'Walking' 
wlk15_WeightGroup2_df.shape
# Out:
# (21982, 13)

# %%
# merging all WeightGroup1 csv files from std_6
std6_WeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_1_std6.csv', 'sub_2_std6.csv', 'sub_3_std6.csv', 'sub_5_std6.csv', 'sub_7_std6.csv', 'sub_8_std6.csv', 'sub_10_std6.csv', 'sub_11_std6.csv', 'sub_12_std6.csv', 'sub_13_std6.csv', 'sub_14_std6.csv', 'sub_15_std6.csv', 'sub_18_std6.csv', 'sub_21_std6.csv', 'sub_23_std6.csv', 'sub_24_std6.csv']), ignore_index=True)
print(std6_WeightGroup1_df)
# Out:
#         Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0                0       2.489271       -1.397067      1.899690   0.104929
# 1                1       2.488154       -1.396068      1.905025   0.105682
# 2                2       2.489687       -1.394939      1.912298   0.106144
# 3                3       2.494505       -1.393874      1.922063   0.106105
# 4                4       2.500577       -1.393094      1.931172   0.105709
# ...            ...            ...             ...           ...        ...
# 150295       10968       0.024580       -1.445235     -1.865114   0.003078
# 150296       10969       0.035625       -1.444928     -1.845826   0.004471
# 150297       10970       0.047078       -1.444934     -1.826624   0.005908
# 150298       10971       0.058243       -1.445177     -1.808854   0.007293
# 150299       10972       0.068046       -1.445550     -1.793355   0.008494
#
# ...

# %%
# Drop first column of dataframe
std6_WeightGroup1_df = std6_WeightGroup1_df.iloc[: , 1:]
std6_WeightGroup1_df.shape
# Out:
# (150300, 12)

# %%
# Add Class Variable "Activity" in dataframe
std6_WeightGroup1_df["Activity"] = 'Standing' 
std6_WeightGroup1_df.shape
# Out:
# (150300, 13)

# %%
# merging all WeightGroup2 csv files from std_6 
std6_WeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_4_std6.csv', 'sub_6_std6.csv', 'sub_9_std6.csv', 'sub_16_std6.csv', 'sub_17_std6.csv', 'sub_19_std6.csv', 'sub_20_std6.csv', 'sub_22_std6.csv']), ignore_index=True)
print(std6_WeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -3.098171       -1.297417     -3.039402  -0.011720
# 1               1      -3.097753       -1.297645     -3.039040  -0.011823
# 2               2      -3.097141       -1.297878     -3.038665  -0.011978
# 3               3      -3.096673       -1.298041     -3.038296  -0.012096
# 4               4      -3.096056       -1.298181     -3.037830  -0.012256
# ...           ...            ...             ...           ...        ...
# 74511        7622      -1.197682       -1.477199     -1.878977  -0.086168
# 74512        7623      -1.272631       -1.480059     -1.949962  -0.085695
# 74513        7624      -1.347158       -1.483424     -2.019999  -0.084103
# 74514        7625      -1.416108       -1.486702     -2.084729  -0.081949
# 74515        7626      -1.480307       -1.489345     -2.145587  -0.079933
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
std6_WeightGroup2_df = std6_WeightGroup2_df.iloc[: , 1:]
std6_WeightGroup2_df.shape
# Out:
# (74516, 12)

# %%
# Add Class Variable "Activity" in dataframe
std6_WeightGroup2_df["Activity"] = 'Standing' 
std6_WeightGroup2_df.shape
# Out:
# (74516, 13)

# %%
# merging all WeightGroup1 csv files from std_14
std14_WeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_1_std14.csv', 'sub_2_std14.csv', 'sub_3_std14.csv', 'sub_5_std14.csv', 'sub_7_std14.csv', 'sub_8_std14.csv', 'sub_10_std14.csv', 'sub_11_std14.csv', 'sub_12_std14.csv', 'sub_13_std14.csv', 'sub_14_std14.csv', 'sub_15_std14.csv', 'sub_18_std14.csv', 'sub_21_std14.csv', 'sub_23_std14.csv', 'sub_24_std14.csv']), ignore_index=True)
print(std14_WeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.573929       -1.051363      1.611548   0.496386
# 1               1       1.573086       -1.051097      1.611145   0.496618
# 2               2       1.574466       -1.050255      1.612825   0.497346
# 3               3       1.574735       -1.053220      1.614236   0.494771
# 4               4       1.577461       -1.054274      1.618206   0.493848
# ...           ...            ...             ...           ...        ...
# 52051        3964      -2.512274       -1.475547      0.560892  -0.055978
# 52052        3965      -2.514569       -1.474699      0.558068  -0.056297
# 52053        3966      -2.517105       -1.473640      0.555248  -0.056716
# 52054        3967      -2.515195       -1.472593      0.557282  -0.057477
# 52055        3968      -2.512655       -1.471566      0.560290  -0.058280
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
std14_WeightGroup1_df = std14_WeightGroup1_df.iloc[: , 1:]
std14_WeightGroup1_df.shape
# Out:
# (52056, 12)

# %%
# Add Class Variable "Activity" in dataframe
std14_WeightGroup1_df["Activity"] = 'Standing' 
std14_WeightGroup1_df.shape
# Out:
# (52056, 13)

# %%
# merging all WeightGroup2 csv files from std_14 
std14_WeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_4_std14.csv', 'sub_6_std14.csv', 'sub_9_std14.csv', 'sub_16_std14.csv', 'sub_17_std14.csv', 'sub_19_std14.csv', 'sub_20_std14.csv', 'sub_22_std14.csv']), ignore_index=True)
print(std14_WeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -2.456270       -1.176206     -2.938302  -0.243283
# 1               1      -2.458436       -1.176633     -2.938910  -0.242389
# 2               2      -2.459613       -1.177493     -2.937843  -0.241537
# 3               3      -2.459663       -1.178411     -2.936332  -0.240988
# 4               4      -2.458772       -1.179260     -2.934724  -0.240757
# ...           ...            ...             ...           ...        ...
# 29550        5774      -0.619835       -1.350551      2.879654  -0.126790
# 29551        5775      -0.619461       -1.350649      2.877945  -0.126668
# 29552        5776      -0.619264       -1.350392      2.876637  -0.126779
# 29553        5777      -0.619338       -1.349851      2.875683  -0.127099
# 29554        5778      -0.619668       -1.349268      2.874892  -0.127489
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
std14_WeightGroup2_df = std14_WeightGroup2_df.iloc[: , 1:]
std14_WeightGroup2_df.shape
# Out:
# (29555, 12)

# %%
# Add Class Variable "Activity" in dataframe
std14_WeightGroup2_df["Activity"] = 'Standing' 
std14_WeightGroup2_df.shape
# Out:
# (29555, 13)

# %%
# merging all WeightGroup1 csv files from sit_5
sit5_WeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_1_sit5.csv', 'sub_2_sit5.csv', 'sub_3_sit5.csv', 'sub_5_sit5.csv', 'sub_7_sit5.csv', 'sub_8_sit5.csv', 'sub_10_sit5.csv', 'sub_11_sit5.csv', 'sub_12_sit5.csv', 'sub_13_sit5.csv', 'sub_14_sit5.csv', 'sub_15_sit5.csv', 'sub_18_sit5.csv', 'sub_21_sit5.csv', 'sub_23_sit5.csv', 'sub_24_sit5.csv']), ignore_index=True)
print(sit5_WeightGroup1_df)
# Out:
#         Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0                0       0.351138       -0.416302     -0.098023   0.314588
# 1                1       0.351219       -0.416372     -0.098025   0.314649
# 2                2       0.351145       -0.416497     -0.098045   0.314567
# 3                3       0.350849       -0.416695     -0.098148   0.314286
# 4                4       0.350859       -0.416863     -0.098022   0.314271
# ...            ...            ...             ...           ...        ...
# 156353       10683      -2.563484       -0.149645     -0.322130  -0.540334
# 156354       10684      -2.559251       -0.157457     -0.316592  -0.543177
# 156355       10685      -2.554478       -0.161579     -0.309695  -0.546746
# 156356       10686      -2.549122       -0.163005     -0.302709  -0.551010
# 156357       10687      -2.542947       -0.165970     -0.295609  -0.555781
#
# ...

# %%
# Drop first column of dataframe
sit5_WeightGroup1_df = sit5_WeightGroup1_df.iloc[: , 1:]
sit5_WeightGroup1_df.shape
# Out:
# (156358, 12)

# %%
# Add Class Variable (Activity) in dataframe
sit5_WeightGroup1_df["Activity"] = 'Sit' 
sit5_WeightGroup1_df.shape
# Out:
# (156358, 13)

# %%
# merging all WeightGroup2 csv files from sit_5 
sit5_WeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_4_sit5.csv', 'sub_6_sit5.csv', 'sub_9_sit5.csv', 'sub_16_sit5.csv', 'sub_17_sit5.csv', 'sub_19_sit5.csv', 'sub_20_sit5.csv', 'sub_22_sit5.csv']), ignore_index=True)
print(sit5_WeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.092006       -0.705577      0.035796   0.675635
# 1               1       1.091942       -0.705698      0.035752   0.675543
# 2               2       1.091795       -0.705777      0.035647   0.675446
# 3               3       1.091758       -0.705802      0.035561   0.675418
# 4               4       1.091751       -0.705894      0.035495   0.675363
# ...           ...            ...             ...           ...        ...
# 78294        8461       0.414219       -0.237713      1.090686   0.391157
# 78295        8462       0.414810       -0.237391      1.089693   0.391714
# 78296        8463       0.415104       -0.237104      1.088961   0.392002
# 78297        8464       0.415130       -0.236966      1.088600   0.392038
# 78298        8465       0.414942       -0.236914      1.088706   0.391876
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
sit5_WeightGroup2_df = sit5_WeightGroup2_df.iloc[: , 1:]
sit5_WeightGroup2_df.shape
# Out:
# (78299, 12)

# %%
# Add Class Variable "Activity" in dataframe
sit5_WeightGroup2_df["Activity"] = 'Sit' 
sit5_WeightGroup2_df.shape
# Out:
# (78299, 13)

# %%
# merging all WeightGroup1 csv files from sit_13
sit13_WeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_1_sit13.csv', 'sub_2_sit13.csv', 'sub_3_sit13.csv', 'sub_5_sit13.csv', 'sub_7_sit13.csv', 'sub_8_sit13.csv', 'sub_10_sit13.csv', 'sub_11_sit13.csv', 'sub_12_sit13.csv', 'sub_13_sit13.csv', 'sub_14_sit13.csv', 'sub_15_sit13.csv', 'sub_18_sit13.csv', 'sub_21_sit13.csv', 'sub_23_sit13.csv', 'sub_24_sit13.csv']), ignore_index=True)
print(sit13_WeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.351138       -0.416302     -0.098023   0.314588
# 1               1       0.351219       -0.416372     -0.098025   0.314649
# 2               2       0.351145       -0.416497     -0.098045   0.314567
# 3               3       0.350849       -0.416695     -0.098148   0.314286
# 4               4       0.350859       -0.416863     -0.098022   0.314271
# ...           ...            ...             ...           ...        ...
# 73504        3381      -2.368280       -0.381075     -0.089417  -0.648402
# 73505        3382      -2.368752       -0.381071     -0.089478  -0.648090
# 73506        3383      -2.369130       -0.381163     -0.089465  -0.647814
# 73507        3384      -2.369372       -0.381295     -0.089468  -0.647619
# 73508        3385      -2.369404       -0.381297     -0.089545  -0.647598
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
sit13_WeightGroup1_df = sit13_WeightGroup1_df.iloc[: , 1:]
sit13_WeightGroup1_df.shape
# Out:
# (73509, 12)

# %%
# Add Class Variable (Activity) in dataframe
sit13_WeightGroup1_df["Activity"] = 'Sit' 
sit13_WeightGroup1_df.shape
# Out:
# (73509, 13)

# %%
# merging all WeightGroup2 csv files from sit_13 
sit13_WeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_4_sit13.csv', 'sub_6_sit13.csv', 'sub_9_sit13.csv', 'sub_16_sit13.csv', 'sub_17_sit13.csv', 'sub_19_sit13.csv', 'sub_20_sit13.csv', 'sub_22_sit13.csv']), ignore_index=True)
print(sit13_WeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.685862       -0.355183      0.612317   0.593808
# 1               1       0.685957       -0.355155      0.612328   0.593884
# 2               2       0.686045       -0.355115      0.612403   0.593956
# 3               3       0.686079       -0.355033      0.612454   0.593999
# 4               4       0.685879       -0.354852      0.612372   0.593894
# ...           ...            ...             ...           ...        ...
# 30607        3552       0.449772        0.012088      0.112036   0.434728
# 30608        3553       0.449075        0.013243      0.111479   0.434094
# 30609        3554       0.448561        0.014333      0.110953   0.433625
# 30610        3555       0.447085        0.015270      0.110621   0.432288
# 30611        3556       0.445072        0.015881      0.110639   0.430468
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
sit13_WeightGroup2_df = sit13_WeightGroup2_df.iloc[: , 1:]
sit13_WeightGroup2_df.shape
# Out:
# (30612, 12)

# %%
# Add Class Variable "Activity" in dataframe
sit13_WeightGroup2_df["Activity"] = 'Sit' 
sit13_WeightGroup2_df.shape
# Out:
# (30612, 13)

# %%
# merging all WeightGroup1 csv files from jog_9
jog9_WeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_1_jog9.csv', 'sub_2_jog9.csv', 'sub_3_jog9.csv', 'sub_5_jog9.csv', 'sub_7_jog9.csv', 'sub_8_jog9.csv', 'sub_10_jog9.csv', 'sub_11_jog9.csv', 'sub_12_jog9.csv', 'sub_13_jog9.csv', 'sub_14_jog9.csv', 'sub_15_jog9.csv', 'sub_18_jog9.csv', 'sub_21_jog9.csv', 'sub_23_jog9.csv', 'sub_24_jog9.csv']), ignore_index=True)
print(jog9_WeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       3.058304       -1.227988      2.570999   0.027964
# 1               1       3.075964       -1.225818      2.615277   0.022178
# 2               2       3.103364       -1.235013      2.651791   0.012594
# 3               3       3.109208       -1.244901      2.678484   0.010366
# 4               4       3.074214       -1.263514      2.661371   0.020364
# ...           ...            ...             ...           ...        ...
# 68477        2838      -1.017175       -1.162354     -1.310722  -0.337852
# 68478        2839      -1.292318       -1.078857     -1.562349  -0.454140
# 68479        2840      -1.403760       -0.951444     -1.709745  -0.572428
# 68480        2841      -1.504000       -0.843886     -1.828078  -0.663082
# 68481        2842      -1.550190       -0.746814     -1.889135  -0.733701
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
jog9_WeightGroup1_df = jog9_WeightGroup1_df.iloc[: , 1:]
jog9_WeightGroup1_df.shape
# Out:
# (68482, 12)

# %%
# Add Class Variable (Activity) in dataframe
jog9_WeightGroup1_df["Activity"] = 'Jogging' 
jog9_WeightGroup1_df.shape
# Out:
# (68482, 13)

# %%
# merging all WeightGroup2 csv files from jog_9 
jog9_WeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_4_jog9.csv', 'sub_6_jog9.csv', 'sub_9_jog9.csv', 'sub_16_jog9.csv', 'sub_17_jog9.csv', 'sub_19_jog9.csv', 'sub_20_jog9.csv', 'sub_22_jog9.csv']), ignore_index=True)
print(jog9_WeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -2.544349       -1.250641      2.175416  -0.176977
# 1               1      -2.524075       -1.187355      2.047589  -0.216610
# 2               2      -2.534324       -1.141923      1.990077  -0.237286
# 3               3      -2.564504       -1.098202      1.960054  -0.248344
# 4               4      -2.558607       -1.062442      1.940199  -0.267954
# ...           ...            ...             ...           ...        ...
# 35840        4808       1.009935       -1.168745     -2.709150   0.331332
# 35841        4809       1.029138       -1.194641     -2.717922   0.314736
# 35842        4810       1.011173       -1.238663     -2.711134   0.276290
# 35843        4811       1.046748       -1.275486     -2.665642   0.251943
# 35844        4812       1.111508       -1.308082     -2.611691   0.232745
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
jog9_WeightGroup2_df = jog9_WeightGroup2_df.iloc[: , 1:]
jog9_WeightGroup2_df.shape
# Out:
# (35845, 12)

# %%
# Add Class Variable "Activity" in dataframe
jog9_WeightGroup2_df["Activity"] = 'Jogging' 
jog9_WeightGroup2_df.shape
# Out:
# (35845, 13)

# %%
# merging all WeightGroup1 csv files from jog_16
jog16_WeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_1_jog16.csv', 'sub_2_jog16.csv', 'sub_3_jog16.csv', 'sub_5_jog16.csv', 'sub_7_jog16.csv', 'sub_8_jog16.csv', 'sub_10_jog16.csv', 'sub_11_jog16.csv', 'sub_12_jog16.csv', 'sub_13_jog16.csv', 'sub_14_jog16.csv', 'sub_15_jog16.csv', 'sub_18_jog16.csv', 'sub_21_jog16.csv', 'sub_23_jog16.csv', 'sub_24_jog16.csv']), ignore_index=True)
print(jog16_WeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       2.135357       -1.138555      1.678900   0.353903
# 1               1       2.162745       -1.152928      1.739330   0.336766
# 2               2       2.175561       -1.166584      1.770651   0.323538
# 3               3       2.105621       -1.194708      1.696332   0.315997
# 4               4       2.021151       -1.202365      1.626949   0.324243
# ...           ...            ...             ...           ...        ...
# 20258         785      -1.553643       -1.207026     -2.015848  -0.355748
# 20259         786      -1.533934       -1.243476     -2.010537  -0.321289
# 20260         787      -1.301587       -1.362634     -1.783378  -0.199218
# 20261         788      -0.524913       -1.486641     -0.952944  -0.042124
# 20262         789       0.683482       -1.435057      0.377682   0.085456
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
jog16_WeightGroup1_df = jog16_WeightGroup1_df.iloc[: , 1:]
jog16_WeightGroup1_df.shape
# Out:
# (20263, 12)

# %%
# Add Class Variable (Activity) in dataframe
jog16_WeightGroup1_df["Activity"] = 'Jogging' 
jog16_WeightGroup1_df.shape
# Out:
# (20263, 13)

# %%
# merging all WeightGroup2 csv files from jog_16 
jog16_WeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_4_jog16.csv', 'sub_6_jog16.csv', 'sub_9_jog16.csv', 'sub_16_jog16.csv', 'sub_17_jog16.csv', 'sub_19_jog16.csv', 'sub_20_jog16.csv', 'sub_22_jog16.csv']), ignore_index=True)
print(jog16_WeightGroup2_df)
# Out:
#       Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0              0       0.912931       -1.254735     -0.524300   0.245955
# 1              1       0.868462       -1.231787     -0.633293   0.253849
# 2              2       0.759872       -1.270963     -0.741842   0.203452
# 3              3       0.710121       -1.304807     -0.759396   0.171367
# 4              4       0.651566       -1.332858     -0.777883   0.142934
# ...          ...            ...             ...           ...        ...
# 9636        1463       2.625511       -1.444273      0.859824   0.062197
# 9637        1464       2.983922       -1.442248      1.179851   0.020106
# 9638        1465      -3.019766       -1.433483      1.426805  -0.016618
# 9639        1466      -2.837716       -1.423747      1.585341  -0.043803
# 9640        1467      -2.751986       -1.425407      1.669631  -0.054978
#
#       gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
jog16_WeightGroup2_df = jog16_WeightGroup2_df.iloc[: , 1:]
jog16_WeightGroup2_df.shape
# Out:
# (9641, 12)

# %%
# Add Class Variable "Activity" in dataframe
jog16_WeightGroup2_df["Activity"] = 'Jogging' 
jog16_WeightGroup2_df.shape
# Out:
# (9641, 13)

# %%
# merging all WeightGroup1 csv files from dws_1
dws1_WeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_1_dws1.csv', 'sub_2_dws1.csv', 'sub_3_dws1.csv', 'sub_5_dws1.csv', 'sub_7_dws1.csv', 'sub_8_dws1.csv', 'sub_10_dws1.csv', 'sub_11_dws1.csv', 'sub_12_dws1.csv', 'sub_13_dws1.csv', 'sub_14_dws1.csv', 'sub_15_dws1.csv', 'sub_18_dws1.csv', 'sub_21_dws1.csv', 'sub_23_dws1.csv', 'sub_24_dws1.csv']), ignore_index=True)
print(dws1_WeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.528132       -0.733896      0.696372   0.741895
# 1               1       1.527992       -0.716987      0.677762   0.753099
# 2               2       1.527765       -0.706999      0.670951   0.759611
# 3               3       1.516768       -0.704678      0.675735   0.760709
# 4               4       1.493941       -0.703918      0.672994   0.760062
# ...           ...            ...             ...           ...        ...
# 33540        1642       1.900272       -1.384036      1.070332   0.175689
# 33541        1643       1.996873       -1.369482      1.160633   0.182080
# 33542        1644       2.074751       -1.350028      1.228313   0.191755
# 33543        1645       2.139869       -1.337114      1.289072   0.195067
# 33544        1646       2.272042       -1.327628      1.417406   0.183965
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws1_WeightGroup1_df = dws1_WeightGroup1_df.iloc[: , 1:]
dws1_WeightGroup1_df.shape
# Out:
# (33545, 12)

# %%
# Add Class Variable (Activity) in dataframe
dws1_WeightGroup1_df["Activity"] = 'Walking_DownStairs' 
dws1_WeightGroup1_df.shape
# Out:
# (33545, 13)

# %%
# merging all WeightGroup2 csv files from dws_1 
dws1_WeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_4_dws1.csv', 'sub_6_dws1.csv', 'sub_9_dws1.csv', 'sub_16_dws1.csv', 'sub_17_dws1.csv', 'sub_19_dws1.csv', 'sub_20_dws1.csv', 'sub_22_dws1.csv']), ignore_index=True)
print(dws1_WeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -1.388134       -1.409321     -1.900903  -0.158069
# 1               1      -1.278818       -1.406745     -1.831680  -0.156377
# 2               2      -1.131389       -1.406811     -1.721617  -0.147717
# 3               3      -0.959996       -1.397211     -1.555533  -0.141464
# 4               4      -0.813195       -1.377542     -1.390822  -0.139507
# ...           ...            ...             ...           ...        ...
# 16696        1819       0.654484       -1.046152     -2.750981   0.304922
# 16697        1820       0.665439       -0.992830     -2.730912   0.337297
# 16698        1821       0.680146       -0.961199     -2.717366   0.360069
# 16699        1822       0.709875       -0.950585     -2.699831   0.378791
# 16700        1823       0.744389       -0.954610     -2.671356   0.391555
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws1_WeightGroup2_df = dws1_WeightGroup2_df.iloc[: , 1:]
dws1_WeightGroup2_df.shape
# Out:
# (16701, 12)

# %%
# Add Class Variable "Activity" in dataframe
dws1_WeightGroup2_df["Activity"] = 'Walking_DownStairs' 
dws1_WeightGroup2_df.shape
# Out:
# (16701, 13)

# %%
# merging all WeightGroup1 csv files from dws_2
dws2_WeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_1_dws2.csv', 'sub_2_dws2.csv', 'sub_3_dws2.csv', 'sub_5_dws2.csv', 'sub_7_dws2.csv', 'sub_8_dws2.csv', 'sub_10_dws2.csv', 'sub_11_dws2.csv', 'sub_12_dws2.csv', 'sub_13_dws2.csv', 'sub_14_dws2.csv', 'sub_15_dws2.csv', 'sub_18_dws2.csv', 'sub_21_dws2.csv', 'sub_23_dws2.csv', 'sub_24_dws2.csv']), ignore_index=True)
print(dws2_WeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.055270       -0.954541     -0.609278   0.031929
# 1               1       0.034557       -0.942493     -0.606960   0.020308
# 2               2       0.016687       -0.959855     -0.610954   0.009572
# 3               3       0.000695       -1.003050     -0.620385   0.000374
# 4               4      -0.017676       -1.060086     -0.634626  -0.008640
# ...           ...            ...             ...           ...        ...
# 38972        1456      -2.717883       -1.332958     -2.303607  -0.096867
# 38973        1457      -2.675661       -1.316127     -2.168156  -0.113179
# 38974        1458      -2.624580       -1.300916     -2.046566  -0.131785
# 38975        1459      -2.553919       -1.289668     -1.899243  -0.153820
# 38976        1460      -2.477694       -1.283688     -1.738934  -0.174494
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws2_WeightGroup1_df = dws2_WeightGroup1_df.iloc[: , 1:]
dws2_WeightGroup1_df.shape
# Out:
# (38977, 12)

# %%
# Add Class Variable (Activity) in dataframe
dws2_WeightGroup1_df["Activity"] = 'Walking_DownStairs' 
dws2_WeightGroup1_df.shape
# Out:
# (38977, 13)

# %%
# merging all WeightGroup2 csv files from dws_2 
dws2_WeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_4_dws2.csv', 'sub_6_dws2.csv', 'sub_9_dws2.csv', 'sub_16_dws2.csv', 'sub_17_dws2.csv', 'sub_19_dws2.csv', 'sub_20_dws2.csv', 'sub_22_dws2.csv']), ignore_index=True)
print(dws2_WeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -0.734981       -1.182156     -1.085416  -0.254097
# 1               1      -0.686981       -1.193032     -1.107441  -0.233919
# 2               2      -0.644928       -1.206407     -1.122956  -0.214230
# 3               3      -0.676227       -1.234493     -1.154440  -0.206527
# 4               4      -0.740896       -1.260205     -1.188608  -0.206273
# ...           ...            ...             ...           ...        ...
# 20126        1915       0.821318       -1.002044      0.010088   0.394260
# 20127        1916       0.813559       -0.945642     -0.012615   0.425298
# 20128        1917       0.802957       -0.911150     -0.011541   0.440879
# 20129        1918       0.783794       -0.898710     -0.016435   0.439548
# 20130        1919       0.765903       -0.900199     -0.037666   0.430781
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws2_WeightGroup2_df = dws2_WeightGroup2_df.iloc[: , 1:]
dws2_WeightGroup2_df.shape
# Out:
# (20131, 12)

# %%
# Add Class Variable "Activity" in dataframe
dws2_WeightGroup2_df["Activity"] = 'Walking_DownStairs' 
dws2_WeightGroup2_df.shape
# Out:
# (20131, 13)

# %%
# merging all WeightGroup1 csv files from dws_11
dws11_WeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_1_dws11.csv', 'sub_2_dws11.csv', 'sub_3_dws11.csv', 'sub_5_dws11.csv', 'sub_7_dws11.csv', 'sub_8_dws11.csv', 'sub_10_dws11.csv', 'sub_11_dws11.csv', 'sub_12_dws11.csv', 'sub_13_dws11.csv', 'sub_14_dws11.csv', 'sub_15_dws11.csv', 'sub_18_dws11.csv', 'sub_21_dws11.csv', 'sub_23_dws11.csv', 'sub_24_dws11.csv']), ignore_index=True)
print(dws11_WeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.086504       -1.172129      1.181660   0.033538
# 1               1       0.059454       -1.146609      1.248254   0.024456
# 2               2       0.029339       -1.130040      1.295114   0.012515
# 3               3      -0.004340       -1.119799      1.327633  -0.001892
# 4               4      -0.041066       -1.118417      1.351262  -0.017945
# ...           ...            ...             ...           ...        ...
# 14698         434      -2.630665       -0.942106     -2.692480  -0.287566
# 14699         435      -2.622877       -0.941469     -2.686673  -0.291808
# 14700         436      -2.632187       -0.962013     -2.683334  -0.278877
# 14701         437      -2.642530       -1.004807     -2.675556  -0.256651
# 14702         438      -2.644099       -1.077019     -2.663269  -0.226183
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws11_WeightGroup1_df = dws11_WeightGroup1_df.iloc[: , 1:]
dws11_WeightGroup1_df.shape
# Out:
# (14703, 12)

# %%
# Add Class Variable (Activity) in dataframe
dws11_WeightGroup1_df["Activity"] = 'Walking_DownStairs' 
dws11_WeightGroup1_df.shape
# Out:
# (14703, 13)

# %%
# merging all WeightGroup2 csv files from dws_11 
dws11_WeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_4_dws11.csv', 'sub_6_dws11.csv', 'sub_9_dws11.csv', 'sub_16_dws11.csv', 'sub_17_dws11.csv', 'sub_19_dws11.csv', 'sub_20_dws11.csv', 'sub_22_dws11.csv']), ignore_index=True)
print(dws11_WeightGroup2_df)
# Out:
#       Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0              0      -1.426021       -1.178927     -1.535913  -0.377913
# 1              1      -1.297726       -1.149504     -1.325689  -0.393781
# 2              2      -1.177693       -1.139341     -1.119103  -0.386289
# 3              3      -1.049576       -1.143759     -0.914439  -0.359173
# 4              4      -0.904011       -1.144656     -0.705606  -0.324819
# ...          ...            ...             ...           ...        ...
# 7794         691       1.198224       -1.289482     -2.144893   0.258573
# 7795         692       1.172314       -1.307875     -2.170818   0.239539
# 7796         693       1.113915       -1.319807     -2.233084   0.222888
# 7797         694       1.069544       -1.320696     -2.305056   0.217053
# 7798         695       0.996454       -1.307672     -2.417663   0.218365
#
#       gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
dws11_WeightGroup2_df = dws11_WeightGroup2_df.iloc[: , 1:]
dws11_WeightGroup2_df.shape
# Out:
# (7799, 12)

# %%
# Add Class Variable "Activity" in dataframe
dws11_WeightGroup2_df["Activity"] = 'Walking_DownStairs' 
dws11_WeightGroup2_df.shape
# Out:
# (7799, 13)

# %%
# merging all WeightGroup1 csv files from ups_3
ups3_WeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_1_ups3.csv', 'sub_2_ups3.csv', 'sub_3_ups3.csv', 'sub_5_ups3.csv', 'sub_7_ups3.csv', 'sub_8_ups3.csv', 'sub_10_ups3.csv', 'sub_11_ups3.csv', 'sub_12_ups3.csv', 'sub_13_ups3.csv', 'sub_14_ups3.csv', 'sub_15_ups3.csv', 'sub_18_ups3.csv', 'sub_21_ups3.csv', 'sub_23_ups3.csv', 'sub_24_ups3.csv']), ignore_index=True)
print(ups3_WeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -2.643769       -1.348560      1.938935  -0.105250
# 1               1      -2.611424       -1.325624      1.946019  -0.122740
# 2               2      -2.544143       -1.316334      2.003067  -0.141604
# 3               3      -2.506960       -1.308531      2.043615  -0.153716
# 4               4      -2.528618       -1.296898      2.026038  -0.155612
# ...           ...            ...             ...           ...        ...
# 38148        1392       1.225887       -1.380504     -0.586724   0.178006
# 38149        1393       1.702697       -1.456976     -0.134149   0.112589
# 38150        1394       2.598022       -1.491832      0.750552   0.040798
# 38151        1395      -2.791966       -1.460973      1.655483  -0.037544
# 38152        1396      -2.489767       -1.380595      1.980176  -0.114689
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups3_WeightGroup1_df = ups3_WeightGroup1_df.iloc[: , 1:]
ups3_WeightGroup1_df.shape
# Out:
# (38153, 12)

# %%
# Add Class Variable (Activity) in dataframe
ups3_WeightGroup1_df["Activity"] = 'Walking_UpStairs' 
ups3_WeightGroup1_df.shape
# Out:
# (38153, 13)

# %%
# merging all WeightGroup2 csv files from ups_3 
ups3_WeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_4_ups3.csv', 'sub_6_ups3.csv', 'sub_9_ups3.csv', 'sub_16_ups3.csv', 'sub_17_ups3.csv', 'sub_19_ups3.csv', 'sub_20_ups3.csv', 'sub_22_ups3.csv']), ignore_index=True)
print(ups3_WeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0      -2.144343       -1.246446     -2.852195  -0.267691
# 1               1      -2.027014       -1.293130     -2.728107  -0.246072
# 2               2      -1.844076       -1.341536     -2.536889  -0.218816
# 3               3      -1.565642       -1.383213     -2.268616  -0.186473
# 4               4      -1.180024       -1.411281     -1.895389  -0.146857
# ...           ...            ...             ...           ...        ...
# 20046        2392       0.710971       -1.053417      3.083730   0.322751
# 20047        2393       0.694973       -0.997367      3.094061   0.347397
# 20048        2394       0.681214       -0.941093      3.101978   0.370846
# 20049        2395       0.663800       -0.883853      3.108506   0.390718
# 20050        2396       0.641690       -0.828455      3.115239   0.404623
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups3_WeightGroup2_df = ups3_WeightGroup2_df.iloc[: , 1:]
ups3_WeightGroup2_df.shape
# Out:
# (20051, 12)

# %%
# Add Class Variable "Activity" in dataframe
ups3_WeightGroup2_df["Activity"] = 'Walking_UpStairs' 
ups3_WeightGroup2_df.shape
# Out:
# (20051, 13)

# %%
# merging all WeightGroup1 csv files from ups_4
ups4_WeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_1_ups4.csv', 'sub_2_ups4.csv', 'sub_3_ups4.csv', 'sub_5_ups4.csv', 'sub_7_ups4.csv', 'sub_8_ups4.csv', 'sub_10_ups4.csv', 'sub_11_ups4.csv', 'sub_12_ups4.csv', 'sub_13_ups4.csv', 'sub_14_ups4.csv', 'sub_15_ups4.csv', 'sub_18_ups4.csv', 'sub_21_ups4.csv', 'sub_23_ups4.csv', 'sub_24_ups4.csv']), ignore_index=True)
print(ups4_WeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.348443       -0.817831      0.539156   0.233475
# 1               1       0.391896       -0.851445      0.553602   0.251660
# 2               2       0.448344       -0.888969      0.574567   0.273181
# 3               3       0.502052       -0.913294      0.588488   0.294097
# 4               4       0.556119       -0.928739      0.603094   0.316126
# ...           ...            ...             ...           ...        ...
# 46956        1507      -2.208286       -0.734780     -0.350465  -0.596249
# 46957        1508      -2.146088       -0.788391     -0.322954  -0.591508
# 46958        1509      -2.094428       -0.834623     -0.287080  -0.581488
# 46959        1510      -2.071408       -0.876276     -0.254023  -0.561480
# 46960        1511      -2.071189       -0.922735     -0.236846  -0.529632
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups4_WeightGroup1_df = ups4_WeightGroup1_df.iloc[: , 1:]
ups4_WeightGroup1_df.shape
# Out:
# (46961, 12)

# %%
# Add Class Variable (Activity) in dataframe
ups4_WeightGroup1_df["Activity"] = 'Walking_UpStairs' 
ups4_WeightGroup1_df.shape
# Out:
# (46961, 13)

# %%
# merging all WeightGroup2 csv files from ups_4 
ups4_WeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_4_ups4.csv', 'sub_6_ups4.csv', 'sub_9_ups4.csv', 'sub_16_ups4.csv', 'sub_17_ups4.csv', 'sub_19_ups4.csv', 'sub_20_ups4.csv', 'sub_22_ups4.csv']), ignore_index=True)
print(ups4_WeightGroup2_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       1.057131       -1.251014     -1.113863   0.273791
# 1               1       1.091380       -1.249078     -1.067816   0.280551
# 2               2       1.027462       -1.255487     -1.141729   0.265451
# 3               3       0.888928       -1.260541     -1.244728   0.237035
# 4               4       0.817754       -1.242255     -1.291977   0.235419
# ...           ...            ...             ...           ...        ...
# 24106        2705       0.962558       -1.348018     -0.212840   0.181314
# 24107        2706       0.904613       -1.280573     -0.297308   0.224978
# 24108        2707       0.895363       -1.204473     -0.330658   0.279540
# 24109        2708       0.916626       -1.133916     -0.317438   0.335764
# 24110        2709       0.943784       -1.071933     -0.282755   0.387423
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups4_WeightGroup2_df = ups4_WeightGroup2_df.iloc[: , 1:]
ups4_WeightGroup2_df.shape
# Out:
# (24111, 12)

# %%
# Add Class Variable "Activity" in dataframe
ups4_WeightGroup2_df["Activity"] = 'Walking_UpStairs' 
ups4_WeightGroup2_df.shape
# Out:
# (24111, 13)

# %%
# merging all WeightGroup1 csv files from ups_12
ups12_WeightGroup1_df = pd.concat(
    map(pd.read_csv, ['sub_1_ups12.csv', 'sub_2_ups12.csv', 'sub_3_ups12.csv', 'sub_5_ups12.csv', 'sub_7_ups12.csv', 'sub_8_ups12.csv', 'sub_10_ups12.csv', 'sub_11_ups12.csv', 'sub_12_ups12.csv', 'sub_13_ups12.csv', 'sub_14_ups12.csv', 'sub_15_ups12.csv', 'sub_18_ups12.csv', 'sub_21_ups12.csv', 'sub_23_ups12.csv', 'sub_24_ups12.csv']), ignore_index=True)
print(ups12_WeightGroup1_df)
# Out:
#        Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0               0       0.838472       -0.901646      0.189667   0.461284
# 1               1       0.901238       -0.900320      0.177763   0.487205
# 2               2       0.993089       -0.914963      0.185652   0.510856
# 3               3       1.029530       -0.921919      0.171090   0.517913
# 4               4       1.052038       -0.927877      0.156188   0.520657
# ...           ...            ...             ...           ...        ...
# 18436         738      -0.476418       -1.215394     -1.091883  -0.159578
# 18437         739      -0.426007       -1.230329     -1.132637  -0.137992
# 18438         740      -0.351505       -1.215819     -1.095573  -0.119672
# 18439         741      -0.329081       -1.205736     -1.106650  -0.115375
# 18440         742      -0.363036       -1.209536     -1.155255  -0.125516
#
#        gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups12_WeightGroup1_df = ups12_WeightGroup1_df.iloc[: , 1:]
ups12_WeightGroup1_df.shape
# Out:
# (18441, 12)

# %%
# Add Class Variable (Activity) in dataframe
ups12_WeightGroup1_df["Activity"] = 'Walking_UpStairs' 
ups12_WeightGroup1_df.shape
# Out:
# (18441, 13)

# %%
# merging all WeightGroup2 csv files from ups_12 
ups12_WeightGroup2_df = pd.concat(
    map(pd.read_csv, ['sub_4_ups12.csv', 'sub_6_ups12.csv', 'sub_9_ups12.csv', 'sub_16_ups12.csv', 'sub_17_ups12.csv', 'sub_19_ups12.csv', 'sub_20_ups12.csv', 'sub_22_ups12.csv']), ignore_index=True)
print(ups12_WeightGroup2_df)
# Out:
#       Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0              0       0.628427       -1.301768     -0.116976   0.156250
# 1              1       0.666273       -1.337807     -0.092065   0.142697
# 2              2       0.688137       -1.376326     -0.085161   0.122725
# 3              3       0.675885       -1.409634     -0.117087   0.100378
# 4              4       0.624714       -1.433519     -0.180724   0.080028
# ...          ...            ...             ...           ...        ...
# 9563        1003      -0.198957       -1.453118      2.183427  -0.023201
# 9564        1004       0.203950       -1.399843      2.576332   0.034453
# 9565        1005       0.420937       -1.351860      2.813387   0.088743
# 9566        1006       0.552714       -1.308184      2.972340   0.136288
# 9567        1007       0.660519       -1.264018      3.092469   0.185274
#
#       gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
# Drop first column of dataframe
ups12_WeightGroup2_df = ups12_WeightGroup2_df.iloc[: , 1:]
ups12_WeightGroup2_df.shape
# Out:
# (9568, 12)

# %%
# Add Class Variable "Activity" in dataframe
ups12_WeightGroup2_df["Activity"] = 'Walking_UpStairs' 
ups12_WeightGroup2_df.shape
# Out:
# (9568, 13)

# %% [markdown]
# **Combining all activities of WeightGroup1 frames in a single frame**

# %%
all_activities_WeightGroup1_frame = [wlk7_WeightGroup1_df, wlk8_WeightGroup1_df, wlk15_WeightGroup1_df, std6_WeightGroup1_df, std14_WeightGroup1_df, sit5_WeightGroup1_df, sit13_WeightGroup1_df, jog9_WeightGroup1_df, jog16_WeightGroup1_df, dws1_WeightGroup1_df, dws2_WeightGroup1_df, dws11_WeightGroup1_df, ups3_WeightGroup1_df, ups4_WeightGroup1_df, ups12_WeightGroup1_df]

all_activities_WeightGroup1_df = pd.concat(all_activities_WeightGroup1_frame)
all_activities_WeightGroup1_df.shape
# Out:
# (938249, 13)

# %%
# Shuffle the dataframe rows 
all_activities_WeightGroup1_df.sample(frac=1) 
all_activities_WeightGroup1_df.shape
# Out:
# (938249, 13)

# %%
all_activities_WeightGroup2_frames = [wlk7_WeightGroup2_df, wlk8_WeightGroup2_df, wlk15_WeightGroup2_df, std6_WeightGroup2_df, std14_WeightGroup2_df, sit5_WeightGroup2_df, sit13_WeightGroup2_df, jog9_WeightGroup2_df, jog16_WeightGroup2_df, dws1_WeightGroup2_df, dws2_WeightGroup2_df, dws11_WeightGroup2_df, ups3_WeightGroup2_df, ups4_WeightGroup2_df, ups12_WeightGroup2_df]

all_activities_WeightGroup2_df = pd.concat(all_activities_WeightGroup2_frames)
all_activities_WeightGroup2_df.shape
# Out:
# (474616, 13)

# %%
# Shuffle the dataframe rows 
all_activities_WeightGroup2_df.sample(frac=1) 
all_activities_WeightGroup2_df.shape
# Out:
# (474616, 13)

# %%
all_activities_WeightGroup2_df.isna().sum().sum()
# Out:
# 0

# %%
all_activities_WeightGroup1_df.isna().sum().sum()
# Out:
# 0

# %%
# print(all_activity_WeightGroup1_df) 
# print(all_activity_WeightGroup2_df)

# %% [markdown]
# **Classification**

# %%
# importing libraries 
import numpy as np
from numpy import mean
from numpy import std
from sklearn import metrics
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier 
from xgboost import XGBClassifier 
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Weight_based classification using five classifiers

# %%
# RF over WeightGroup1 data

# %%
# Preparing Input and Output Splits 
X = all_activities_WeightGroup1_df.iloc[:, :-1].values
y = all_activities_WeightGroup1_df.iloc[:, -1].values

# %%
X.shape, y.shape
# Out:
# ((938249, 12), (938249,))

# %%
# Train Test Splits with a ratio of 70:30 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((656774, 12), (281475, 12), (656774,), (281475,))

# %%
# define the model applying Random Forest 
rf = RandomForestClassifier() 
gnb = GaussianNB() 
lr = LogisticRegression() 
ab = AdaBoostClassifier()
dt = DecisionTreeClassifier()
bagging = BaggingClassifier()
xgb = XGBClassifier() 
lgbm = LGBMClassifier()

# %%
#Train the model using the training sets
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#Predict the response for test dataset 
y_pred = rf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9429007904787281

# %%
#Train the model using the training sets
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#Predict the response for test dataset 
y_pred = gnb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7114521715960564

# %%
#Train the model using the training sets
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Predict the response for test dataset 
y_pred = lr.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5398916422417621

# %%
#Train the model using the training sets
ab.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
#Predict the response for test dataset 
y_pred = ab.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5572644106936673

# %%
#Train the model using the training sets
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Predict the response for test dataset 
y_pred = dt.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8693205435651479

# %%
#Train the model using the training sets
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
#Predict the response for test dataset 
y_pred = xgb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7824389377386979

# %%
#Train the model using the training sets
lgbm.fit(X_train, y_train)
# Out:
# LGBMClassifier()

# %%
#Predict the response for test dataset 
y_pred = lgbm.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8603002042810196

# %%
#Train the model using the training sets
bagging.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
#Predict the response for test dataset 
y_pred = bagging.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9115836219912958

# %%
# RF over WeightGroup2 data

# %%
# Preparing Input and Output Splits 
X_WeightGroup2 = all_activities_WeightGroup2_df.iloc[:, :-1].values 
y_WeightGroup2 = all_activities_WeightGroup2_df.iloc[:, -1].values

# %%
# Train Test Splits with a ratio of 70:30 
X_train, X_test, y_train, y_test = train_test_split(X_WeightGroup2, y_WeightGroup2, test_size = 0.30)

# %%
#Train the model using the training sets
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#Predict the response for test dataset
y_pred = rf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9467078695087263

# %%
#Train the model using the training sets
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#Predict the response for test dataset
y_pred = gnb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7406468377989255

# %%
#Train the model using the training sets
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Predict the response for test dataset
y_pred = lr.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5648066860975524

# %%
#Train the model using the training sets
ab.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
#Predict the response for test dataset
y_pred = ab.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5139797029181444

# %%
#Train the model using the training sets
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Predict the response for test dataset
y_pred = dt.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8844119815991853

# %%
#Train the model using the training sets
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
#Predict the response for test dataset
y_pred = xgb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8285001931383221

# %%
#Train the model using the training sets
lgbm.fit(X_train, y_train)
# Out:
# LGBMClassifier()

# %%
# Predict the response for test dataset
y_pred = lgbm.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.890676686448713

# %%
#Train the model using the training sets
bagging.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
#Predict the response for test dataset
y_pred = bagging.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.922484812304667

# %%
# Training on WeightGroup1 data and testing on WeightGroup2

# %%
# Preparing Input and Output Splits 
X_all_WeightGroup1_train = all_activities_WeightGroup1_df.iloc[:, :-1].values
y_all_WeightGroup1_train = all_activities_WeightGroup1_df.iloc[:, -1].values

# %%
# Preparing Input and Output Splits 
X_all_WeightGroup2_test = all_activities_WeightGroup2_df.iloc[:, :-1].values
y_all_WeightGroup2_test = all_activities_WeightGroup2_df.iloc[:, -1].values

# %%
#Train the model using the training sets
rf.fit(X_all_WeightGroup1_train, y_all_WeightGroup1_train)
# Out:
# RandomForestClassifier()

# %%
#Predict the response for test dataset 
y_pred = rf.predict(X_all_WeightGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_WeightGroup2_test, y_pred))
# Out:
# Accuracy: 0.7609204072344801

# %%
#Train the model using the training sets
gnb.fit(X_all_WeightGroup1_train, y_all_WeightGroup1_train)
# Out:
# GaussianNB()

# %%
#Predict the response for test dataset 
y_pred = gnb.predict(X_all_WeightGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_WeightGroup2_test, y_pred))
# Out:
# Accuracy: 0.7007875840679623

# %%
#Train the model using the training sets
lr.fit(X_all_WeightGroup1_train, y_all_WeightGroup1_train)
# Out:
# LogisticRegression()

# %%
#Predict the response for test dataset 
y_pred = lr.predict(X_all_WeightGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_WeightGroup2_test, y_pred))
# Out:
# Accuracy: 0.5213730679117434

# %%
#Train the model using the training sets
ab.fit(X_all_WeightGroup1_train, y_all_WeightGroup1_train)
# Out:
# AdaBoostClassifier()

# %%
#Predict the response for test dataset 
y_pred = ab.predict(X_all_WeightGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_WeightGroup2_test, y_pred))
# Out:
# Accuracy: 0.6414069479326445

# %%
#Train the model using the training sets
dt.fit(X_all_WeightGroup1_train, y_all_WeightGroup1_train)
# Out:
# DecisionTreeClassifier()

# %%
#Predict the response for test dataset 
y_pred = dt.predict(X_all_WeightGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_WeightGroup2_test, y_pred))
# Out:
# Accuracy: 0.6770799973030829

# %%
#Train the model using the training sets
xgb.fit(X_all_WeightGroup1_train, y_all_WeightGroup1_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
#Predict the response for test dataset 
y_pred = xgb.predict(X_all_WeightGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_WeightGroup2_test, y_pred))
# Out:
# Accuracy: 0.731778953933285

# %%
#Train the model using the training sets
lgbm.fit(X_all_WeightGroup1_train, y_all_WeightGroup1_train)
# Out:
# LGBMClassifier()

# %%
#Predict the response for test dataset 
y_pred = lgbm.predict(X_all_WeightGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_WeightGroup2_test, y_pred))
# Out:
# Accuracy: 0.7481732600670858

# %%
#Train the model using the training sets
bagging.fit(X_all_WeightGroup1_train, y_all_WeightGroup1_train)
# Out:
# BaggingClassifier()

# %%
# Predict the response for test dataset 
y_pred = bagging.predict(X_all_WeightGroup2_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_WeightGroup2_test, y_pred))
# Out:
# Accuracy: 0.7327713351425152

# %%
# Training on WeightGroup2 data and testing on WeightGroup1

# %%
# Preparing Input and Output Splits 
X_all_WeightGroup1_test = all_activities_WeightGroup1_df.iloc[:, :-1].values
y_all_WeightGroup1_test = all_activities_WeightGroup1_df.iloc[:, -1].values

# %%
# Preparing Input and Output Splits 
X_all_WeightGroup2_train = all_activities_WeightGroup2_df.iloc[:, :-1].values
y_all_WeightGroup2_train = all_activities_WeightGroup2_df.iloc[:, -1].values

# %%
#Train the model using the training sets
rf.fit(X_all_WeightGroup2_train, y_all_WeightGroup2_train)
# Out:
# RandomForestClassifier()

# %%
#Predict the response for test dataset 
y_pred = rf.predict(X_all_WeightGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_WeightGroup1_test, y_pred))
# Out:
# Accuracy: 0.6520507882235952

# %%
#Train the model using the training sets
gnb.fit(X_all_WeightGroup2_train, y_all_WeightGroup2_train)
# Out:
# GaussianNB()

# %%
#Predict the response for test dataset 
y_pred = gnb.predict(X_all_WeightGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_WeightGroup1_test, y_pred))
# Out:
# Accuracy: 0.6899714254957906

# %%
#Train the model using the training sets
lr.fit(X_all_WeightGroup2_train, y_all_WeightGroup2_train)
# Out:
# LogisticRegression()

# %%
#Predict the response for test dataset 
y_pred = lr.predict(X_all_WeightGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_WeightGroup1_test, y_pred))
# Out:
# Accuracy: 0.5064934788099961

# %%
#Train the model using the training sets
ab.fit(X_all_WeightGroup2_train, y_all_WeightGroup2_train)
# Out:
# AdaBoostClassifier()

# %%
#Predict the response for test dataset 
y_pred = ab.predict(X_all_WeightGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_WeightGroup1_test, y_pred))
# Out:
# Accuracy: 0.4447294907854951

# %%
#Train the model using the training sets
dt.fit(X_all_WeightGroup2_train, y_all_WeightGroup2_train)
# Out:
# DecisionTreeClassifier()

# %%
#Predict the response for test dataset 
y_pred = dt.predict(X_all_WeightGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_WeightGroup1_test, y_pred))
# Out:
# Accuracy: 0.5553984070326747

# %%
#Train the model using the training sets
xgb.fit(X_all_WeightGroup2_train, y_all_WeightGroup2_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
#Predict the response for test dataset 
y_pred = xgb.predict(X_all_WeightGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_WeightGroup1_test, y_pred))
# Out:
# Accuracy: 0.7006050632614583

# %%
#Train the model using the training sets
lgbm.fit(X_all_WeightGroup2_train, y_all_WeightGroup2_train)
# Out:
# LGBMClassifier()

# %%
#Predict the response for test dataset 
y_pred = lgbm.predict(X_all_WeightGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_WeightGroup1_test, y_pred))
# Out:
# Accuracy: 0.6791480726331709

# %%
#Train the model using the training sets
bagging.fit(X_all_WeightGroup2_train, y_all_WeightGroup2_train)
# Out:
# BaggingClassifier()

# %%
#Predict the response for test dataset 
y_pred = bagging.predict(X_all_WeightGroup1_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_all_WeightGroup1_test, y_pred))
# Out:
# Accuracy: 0.6262740487866227

# %%
# Combining data of all activities and both groups

# %%
all_activities_both_WeightGroups_frame = [all_activities_WeightGroup1_df, all_activities_WeightGroup2_df]

all_activities_both_WeightGroups_df = pd.concat(all_activities_both_WeightGroups_frame)
all_activities_both_WeightGroups_df.shape
# Out:
# (1412865, 13)

# %%
X = all_activities_both_WeightGroups_df.iloc[:, :-1].values
y = all_activities_both_WeightGroups_df.iloc[:, -1].values

# %%
X.shape, y.shape
# Out:
# ((1412865, 12), (1412865,))

# %%
# Train Test Splits with a ratio of 70:30 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((989005, 12), (423860, 12), (989005,), (423860,))

# %%
#Train the model using the training sets
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#Predict the response for test dataset 
y_pred = rf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9313853630915868

# %%
#Train the model using the training sets
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#Predict the response for test dataset 
y_pred = gnb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7267918652385221

# %%
#Train the model using the training sets
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Predict the response for test dataset 
y_pred = lr.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5427688387675176

# %%
#Train the model using the training sets
ab.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
#Predict the response for test dataset 
y_pred = ab.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7016019440381258

# %%
#Train the model using the training sets
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Predict the response for test dataset 
y_pred = dt.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8555254093332704

# %%
#Train the model using the training sets
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
#Predict the response for test dataset 
y_pred = xgb.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7820978625017695

# %%
#Train the model using the training sets
lgbm.fit(X_train, y_train)
# Out:
# LGBMClassifier()

# %%
#Predict the response for test dataset 
y_pred = lgbm.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8429976879158213

# %%
#Train the model using the training sets
bagging.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
#Predict the response for test dataset 
y_pred = bagging.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9022861322134668
